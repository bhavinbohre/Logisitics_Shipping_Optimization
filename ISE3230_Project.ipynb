# %%
# AI Disclaimer: As per the syllabus, our group used ChatGPT to assist with aggregating and cleaning the dataset using pandas
import pandas as pd
import gurobipy as gp
from gurobipy import GRB

# Load in the data
df = pd.read_csv("logistics_shipments_dataset.csv")

# Get rid of extra whitespace and clean the text
for column in ['Origin_Warehouse', 'Destination', 'Carrier']:
    df[column] = df[column].astype(str).str.replace(r"\s+", " ", regex = True).str.strip()

# Get all distinct names for origin warehouses, destination warehouses, and carriers
origins = sorted(df['Origin_Warehouse'].unique())
destinations = sorted(df['Destination'].unique())
carriers = sorted(df['Carrier'].unique())

# Map the key names to numeric index values in a dictionary
origin_index = {o: i for i, o in enumerate(origins)}
destination_index = {d: j for j, d in enumerate(destinations)}
carrier_index = {c: k for k, c in enumerate(carriers)}

# Reverse the mapping of the dictionary so index value is the key and name is the value
index_origin = {i: o for o, i in origin_index.items()}
index_destination = {j: d for d, j in destination_index.items()}
index_carrier = {k: c for c, k in carrier_index.items()}

# Length of each set for the origin, destination, and carrier
origins_len = len(origins)
dest_len = len(destinations)
carrier_len = len(carriers)

# Supply Capacity at each origin warehouse (S_i)
S = df.groupby('Origin_Warehouse')["Weight_kg"].sum().reindex(origins).fillna(0).tolist()

# Demand Capacity at each destination warehouse (D_j)
D = df.groupby('Destination')["Weight_kg"].sum().reindex(destinations).fillna(0).tolist()

# Making sure to balance supply and demand for a feasible and fair model
total_supply_kg = sum(S)
total_demand_kg = sum(D)

if total_demand_kg > 0:
    sd_ratio = total_supply_kg / total_demand_kg
    D = [d * sd_ratio for d in D]

# Carrier capacity for each carrier (C_k)
C = df.groupby("Carrier")["Weight_kg"].sum().reindex(carriers).fillna(0).tolist()

# Initialize a three-dimensional matrix for parameters c, t, p, g, and Y
co2_per_kg = [[[0 for k in carriers] for j in destinations] for i in origins]
transit_time = [[[0 for k in carriers] for j in destinations] for i in origins]
reliability = [[[0 for k in carriers] for j in destinations] for i in origins]
cost_per_kg = [[[0 for k in carriers] for j in destinations] for i in origins]
route_capacity = [[[0 for k in carriers] for j in destinations] for i in origins]

# CO2 factor per mile for different carriers (used in c_ijk calculation)
co2_factor = {'Amazon Logistics': 0.05, 'DHL': 0.15, 'FedEx': 0.08, 'LaserShip': 0.06, 'OnTrac': 0.12, 'UPS': 0.10, 'USPS': 0.11}

# Set minimum reliability rate for deliveries
R_min = 0.85

# Set the average transportation time in days for deliveries
T_average = 5

# Set the maximum C02 pollution allowed in kilograms of C02 (total supply * scaling constant)
P_max = total_supply_kg * 5

# Function to help clean missing values
def clean(x, def_value):
    if x is None:
        return def_value
    if pd.isna(x):
        return def_value
    return x

# Fill in parameters c, t, p, g, and Y for a route-carrier combination
for o in origins:
    for d in destinations:
        for c in carriers:

            # Set indexes for variables i, j, and k
            i = origin_index[o]
            j = destination_index[d]
            k = carrier_index[c]

            # Get the subset of data for that particular route-carrier combination 
            sub_df = df[(df['Origin_Warehouse'] == o) & (df['Destination'] == d) & (df['Carrier'] == c)]

            # If the subset is empty for a route-carrier combination, then fill c, t, p, g, and Y with constant average values
            if sub_df.empty:
                co2_per_kg[i][j][k] = 0.3
                transit_time[i][j][k] = 5
                reliability[i][j][k] = 0.775
                cost_per_kg[i][j][k] = 5
                route_capacity[i][j][k] = 25000
                continue


            # CO2/kilogram (c_ijk)
            avg_dist = clean(sub_df['Distance_miles'].mean(), 900)
            co2_per_kg[i][j][k] = avg_dist * co2_factor.get(c, 0.3)

            # Transit time (t_ijk)
            transit_time[i][j][k] = clean(sub_df['Transit_Days'].mean(), 5)

            # Reliability rate (p_ijk)
            delivered = sub_df[sub_df['Status'] == 'Delivered'].shape[0]
            total = sub_df.shape[0]
            if total > 0:
                reliability[i][j][k] = delivered / total
            else:
                reliability[i][j][k] = 0.775

            # Cost/kilogram (g_ijk)
            avg_cost = clean(sub_df['Cost'].mean(), 5)
            avg_weight = clean(sub_df['Weight_kg'].mean(), 1)
            cost_per_kg[i][j][k] = avg_cost / avg_weight

            # Route capacity (Y_ijk)
            avg_weight = clean(sub_df['Weight_kg'].mean(), 0)
            route_capacity[i][j][k] = max(avg_weight, 25000)

# Initialize model
m = gp.Model("Shipping")
m.Params.LogToConsole = 0

# Decision variable (x_ijk) for kilograms to be shipped on a route using a specific carrier
x = m.addVars(origins_len, dest_len, carrier_len, lb = 0, name = "x")

# Objective Function
m.setObjective(gp.quicksum(cost_per_kg[i][j][k] * x[i,j,k] for i in range(origins_len) for j in range(dest_len) for k in range(carrier_len)), GRB.MINIMIZE)

# Supply Constraint
for i in range(origins_len):
    m.addConstr(gp.quicksum(x[i,j,k] for j in range(dest_len) for k in range(carrier_len)) <= S[i])

# Demand Constraint
for j in range(dest_len):
    m.addConstr(gp.quicksum(x[i,j,k] for i in range(origins_len) for k in range(carrier_len)) == D[j])

# Carrier Capacity Constraint
for k in range(carrier_len):
    m.addConstr(gp.quicksum(x[i,j,k] for i in range(origins_len) for j in range(dest_len)) <= C[k])

# C02 Constraint
m.addConstr(gp.quicksum(co2_per_kg[i][j][k] * x[i,j,k] for i in range(origins_len) for j in range(dest_len) for k in range(carrier_len)) <= P_max)

# Transit Time Constraint
total_kg = gp.quicksum(x[i,j,k] for i in range(origins_len) for j in range(dest_len) for k in range(carrier_len))

m.addConstr(gp.quicksum(transit_time[i][j][k] * x[i,j,k] for i in range(origins_len) for j in range(dest_len) for k in range(carrier_len)) <= T_average * total_kg)

# Reliability Constraint
m.addConstr(gp.quicksum(reliability[i][j][k] * x[i,j,k] for i in range(origins_len) for j in range(dest_len) for k in range(carrier_len)) >= R_min * total_kg)

# Route Capacity Constraint
for i in range(origins_len):
    for j in range(dest_len):
        for k in range(carrier_len):
            m.addConstr(x[i,j,k] <= route_capacity[i][j][k])

# Optimize model
m.optimize()

# Print results for optimal shipping routes and weights shipped for chosen routes
print("\nOptimal Shipping Cost:", m.objVal)
print("\nShipment Plan:")
for i in range(origins_len):
    for j in range(dest_len):
        for k in range(carrier_len):
            cost = x[i,j,k].x
            if cost > 0:
                print(f"{index_origin[i]} to {index_destination[j]} using {index_carrier[k]}: {cost:.2f} kg")

# Print the reduced costs
print("\nReduced Costs:")
for i in range(origins_len):
    for j in range(dest_len):
        for k in range(carrier_len):
            rc = x[i,j,k].RC
            print(f"{index_origin[i]} to {index_destination[j]} using {index_carrier[k]}: Reduced Cost = {rc:.2f}")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2700305
# Academic license - for non-commercial use only - expires 2026-08-27
# Set parameter LogToConsole to value 0
#
# Optimal Shipping Cost: 216003.9765173699
#
# Shipment Plan:
# Warehouse_ATL to Denver using OnTrac: 1177.88 kg
# Warehouse_ATL to Houston using Amazon Logistics: 1508.37 kg
# Warehouse_ATL to Portland using DHL: 616.95 kg
# Warehouse_ATL to Seattle using USPS: 3046.90 kg
# Warehouse_BOS to Boston using UPS: 2272.23 kg
# Warehouse_BOS to New York using USPS: 2876.31 kg
# Warehouse_BOS to Phoenix using FedEx: 4767.70 kg
# Warehouse_BOS to Portland using FedEx: 46.36 kg
# Warehouse_CHI to Chicago using LaserShip: 4343.00 kg
# Warehouse_CHI to Detroit using DHL: 1256.21 kg
# Warehouse_CHI to New York using UPS: 79.09 kg
# Warehouse_DEN to Miami using LaserShip: 3161.40 kg
# Warehouse_DEN to Portland using Amazon Logistics: 1922.80 kg
# Warehouse_HOU to Denver using USPS: 794.30 kg
# Warehouse_HOU to Los Angeles using FedEx: 3379.49 kg
# Warehouse_HOU to Portland using OnTrac: 1391.89 kg
# Warehouse_HOU to San Francisco using DHL: 148.62 kg
# Warehouse_LA to Atlanta using OnTrac: 3222.54 kg
# Warehouse_LA to Boston using FedEx: 1978.57 kg
# Warehouse_LA to Detroit using OnTrac: 2151.89 kg
# Warehouse_MIA to Denver using DHL: 1627.92 kg
# Warehouse_MIA to San Francisco using FedEx: 3478.88 kg
# Warehouse_NYC to Boston using Amazon Logistics: 3758.23 kg
# Warehouse_NYC to Boston using UPS: 892.17 kg
# Warehouse_SEA to Atlanta using USPS: 357.06 kg
# Warehouse_SEA to Los Angeles using UPS: 18.74 kg
# Warehouse_SEA to Minneapolis using LaserShip: 1280.70 kg
# Warehouse_SEA to Minneapolis using UPS: 3068.20 kg
# Warehouse_SF to Dallas using DHL: 3380.70 kg
# Warehouse_SF to Houston using USPS: 2117.03 kg
# Warehouse_SF to Los Angeles using UPS: 247.47 kg
#
# Reduced Costs:
# Warehouse_ATL to Atlanta using Amazon Logistics: Reduced Cost = 16.82
# Warehouse_ATL to Atlanta using DHL: Reduced Cost = 0.00
# Warehouse_ATL to Atlanta using FedEx: Reduced Cost = 30.38
# Warehouse_ATL to Atlanta using LaserShip: Reduced Cost = 1.00
# Warehouse_ATL to Atlanta using OnTrac: Reduced Cost = 35.30
# Warehouse_ATL to Atlanta using UPS: Reduced Cost = 34.75
# Warehouse_ATL to Atlanta using USPS: Reduced Cost = 6.35
# Warehouse_ATL to Boston using Amazon Logistics: Reduced Cost = 21.32
# Warehouse_ATL to Boston using DHL: Reduced Cost = 46.60
# Warehouse_ATL to Boston using FedEx: Reduced Cost = 21.10
# Warehouse_ATL to Boston using LaserShip: Reduced Cost = 8.29
# Warehouse_ATL to Boston using OnTrac: Reduced Cost = 52.45
# Warehouse_ATL to Boston using UPS: Reduced Cost = 25.79
# Warehouse_ATL to Boston using USPS: Reduced Cost = 34.15
# Warehouse_ATL to Chicago using Amazon Logistics: Reduced Cost = 18.46
# Warehouse_ATL to Chicago using DHL: Reduced Cost = 35.63
# Warehouse_ATL to Chicago using FedEx: Reduced Cost = 0.29
# Warehouse_ATL to Chicago using LaserShip: Reduced Cost = 19.62
# Warehouse_ATL to Chicago using OnTrac: Reduced Cost = 1.53
# Warehouse_ATL to Chicago using UPS: Reduced Cost = 3.96
# Warehouse_ATL to Chicago using USPS: Reduced Cost = 10.57
# Warehouse_ATL to Dallas using Amazon Logistics: Reduced Cost = 14.71
# Warehouse_ATL to Dallas using DHL: Reduced Cost = 69.71
# Warehouse_ATL to Dallas using FedEx: Reduced Cost = 31.00
# Warehouse_ATL to Dallas using LaserShip: Reduced Cost = 16.97
# Warehouse_ATL to Dallas using OnTrac: Reduced Cost = 22.16
# Warehouse_ATL to Dallas using UPS: Reduced Cost = 12.49
# Warehouse_ATL to Dallas using USPS: Reduced Cost = 42.35
# Warehouse_ATL to Denver using Amazon Logistics: Reduced Cost = 21.48
# Warehouse_ATL to Denver using DHL: Reduced Cost = 36.47
# Warehouse_ATL to Denver using FedEx: Reduced Cost = 22.24
# Warehouse_ATL to Denver using LaserShip: Reduced Cost = 5.84
# Warehouse_ATL to Denver using OnTrac: Reduced Cost = 0.00
# Warehouse_ATL to Denver using UPS: Reduced Cost = 3.03
# Warehouse_ATL to Denver using USPS: Reduced Cost = 0.00
# Warehouse_ATL to Detroit using Amazon Logistics: Reduced Cost = 13.31
# Warehouse_ATL to Detroit using DHL: Reduced Cost = 25.72
# Warehouse_ATL to Detroit using FedEx: Reduced Cost = 21.70
# Warehouse_ATL to Detroit using LaserShip: Reduced Cost = 18.33
# Warehouse_ATL to Detroit using OnTrac: Reduced Cost = 13.92
# Warehouse_ATL to Detroit using UPS: Reduced Cost = 0.00
# Warehouse_ATL to Detroit using USPS: Reduced Cost = 36.39
# Warehouse_ATL to Houston using Amazon Logistics: Reduced Cost = 0.00
# Warehouse_ATL to Houston using DHL: Reduced Cost = 51.39
# Warehouse_ATL to Houston using FedEx: Reduced Cost = 16.79
# Warehouse_ATL to Houston using LaserShip: Reduced Cost = 8.01
# Warehouse_ATL to Houston using OnTrac: Reduced Cost = 38.38
# Warehouse_ATL to Houston using UPS: Reduced Cost = 32.17
# Warehouse_ATL to Houston using USPS: Reduced Cost = 7.79
# Warehouse_ATL to Los Angeles using Amazon Logistics: Reduced Cost = 12.09
# Warehouse_ATL to Los Angeles using DHL: Reduced Cost = 0.00
# Warehouse_ATL to Los Angeles using FedEx: Reduced Cost = 16.76
# Warehouse_ATL to Los Angeles using LaserShip: Reduced Cost = 1.00
# Warehouse_ATL to Los Angeles using OnTrac: Reduced Cost = 9.44
# Warehouse_ATL to Los Angeles using UPS: Reduced Cost = 0.00
# Warehouse_ATL to Los Angeles using USPS: Reduced Cost = 19.96
# Warehouse_ATL to Miami using Amazon Logistics: Reduced Cost = 9.54
# Warehouse_ATL to Miami using DHL: Reduced Cost = 54.38
# Warehouse_ATL to Miami using FedEx: Reduced Cost = 15.54
# Warehouse_ATL to Miami using LaserShip: Reduced Cost = 26.49
# Warehouse_ATL to Miami using OnTrac: Reduced Cost = 24.30
# Warehouse_ATL to Miami using UPS: Reduced Cost = 12.33
# Warehouse_ATL to Miami using USPS: Reduced Cost = 24.79
# Warehouse_ATL to Minneapolis using Amazon Logistics: Reduced Cost = 11.30
# Warehouse_ATL to Minneapolis using DHL: Reduced Cost = 26.78
# Warehouse_ATL to Minneapolis using FedEx: Reduced Cost = 4.76
# Warehouse_ATL to Minneapolis using LaserShip: Reduced Cost = 13.66
# Warehouse_ATL to Minneapolis using OnTrac: Reduced Cost = 21.68
# Warehouse_ATL to Minneapolis using UPS: Reduced Cost = 40.37
# Warehouse_ATL to Minneapolis using USPS: Reduced Cost = 21.96
# Warehouse_ATL to New York using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_ATL to New York using DHL: Reduced Cost = 55.47
# Warehouse_ATL to New York using FedEx: Reduced Cost = 22.27
# Warehouse_ATL to New York using LaserShip: Reduced Cost = 4.53
# Warehouse_ATL to New York using OnTrac: Reduced Cost = 12.32
# Warehouse_ATL to New York using UPS: Reduced Cost = 20.20
# Warehouse_ATL to New York using USPS: Reduced Cost = 0.00
# Warehouse_ATL to Phoenix using Amazon Logistics: Reduced Cost = 0.86
# Warehouse_ATL to Phoenix using DHL: Reduced Cost = 92.24
# Warehouse_ATL to Phoenix using FedEx: Reduced Cost = 17.45
# Warehouse_ATL to Phoenix using LaserShip: Reduced Cost = 16.90
# Warehouse_ATL to Phoenix using OnTrac: Reduced Cost = 24.61
# Warehouse_ATL to Phoenix using UPS: Reduced Cost = 26.97
# Warehouse_ATL to Phoenix using USPS: Reduced Cost = 21.04
# Warehouse_ATL to Portland using Amazon Logistics: Reduced Cost = 25.29
# Warehouse_ATL to Portland using DHL: Reduced Cost = 0.00
# Warehouse_ATL to Portland using FedEx: Reduced Cost = 16.06
# Warehouse_ATL to Portland using LaserShip: Reduced Cost = 40.04
# Warehouse_ATL to Portland using OnTrac: Reduced Cost = 0.06
# Warehouse_ATL to Portland using UPS: Reduced Cost = 3.41
# Warehouse_ATL to Portland using USPS: Reduced Cost = 25.51
# Warehouse_ATL to San Francisco using Amazon Logistics: Reduced Cost = 0.24
# Warehouse_ATL to San Francisco using DHL: Reduced Cost = 57.30
# Warehouse_ATL to San Francisco using FedEx: Reduced Cost = 11.13
# Warehouse_ATL to San Francisco using LaserShip: Reduced Cost = 21.12
# Warehouse_ATL to San Francisco using OnTrac: Reduced Cost = 12.64
# Warehouse_ATL to San Francisco using UPS: Reduced Cost = 28.87
# Warehouse_ATL to San Francisco using USPS: Reduced Cost = 23.63
# Warehouse_ATL to Seattle using Amazon Logistics: Reduced Cost = 15.00
# Warehouse_ATL to Seattle using DHL: Reduced Cost = 33.03
# Warehouse_ATL to Seattle using FedEx: Reduced Cost = 13.45
# Warehouse_ATL to Seattle using LaserShip: Reduced Cost = 11.80
# Warehouse_ATL to Seattle using OnTrac: Reduced Cost = 3.12
# Warehouse_ATL to Seattle using UPS: Reduced Cost = 106.27
# Warehouse_ATL to Seattle using USPS: Reduced Cost = 0.00
# Warehouse_BOS to Atlanta using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_BOS to Atlanta using DHL: Reduced Cost = 25.41
# Warehouse_BOS to Atlanta using FedEx: Reduced Cost = 0.00
# Warehouse_BOS to Atlanta using LaserShip: Reduced Cost = 14.89
# Warehouse_BOS to Atlanta using OnTrac: Reduced Cost = 38.15
# Warehouse_BOS to Atlanta using UPS: Reduced Cost = 16.36
# Warehouse_BOS to Atlanta using USPS: Reduced Cost = 10.21
# Warehouse_BOS to Boston using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_BOS to Boston using DHL: Reduced Cost = 62.71
# Warehouse_BOS to Boston using FedEx: Reduced Cost = 12.57
# Warehouse_BOS to Boston using LaserShip: Reduced Cost = 4.98
# Warehouse_BOS to Boston using OnTrac: Reduced Cost = 50.78
# Warehouse_BOS to Boston using UPS: Reduced Cost = 0.00
# Warehouse_BOS to Boston using USPS: Reduced Cost = 29.37
# Warehouse_BOS to Chicago using Amazon Logistics: Reduced Cost = 15.83
# Warehouse_BOS to Chicago using DHL: Reduced Cost = 31.53
# Warehouse_BOS to Chicago using FedEx: Reduced Cost = 28.58
# Warehouse_BOS to Chicago using LaserShip: Reduced Cost = 20.34
# Warehouse_BOS to Chicago using OnTrac: Reduced Cost = 13.71
# Warehouse_BOS to Chicago using UPS: Reduced Cost = 18.06
# Warehouse_BOS to Chicago using USPS: Reduced Cost = 37.19
# Warehouse_BOS to Dallas using Amazon Logistics: Reduced Cost = 3.44
# Warehouse_BOS to Dallas using DHL: Reduced Cost = 46.92
# Warehouse_BOS to Dallas using FedEx: Reduced Cost = 22.69
# Warehouse_BOS to Dallas using LaserShip: Reduced Cost = 22.14
# Warehouse_BOS to Dallas using OnTrac: Reduced Cost = 9.56
# Warehouse_BOS to Dallas using UPS: Reduced Cost = 41.03
# Warehouse_BOS to Dallas using USPS: Reduced Cost = 0.00
# Warehouse_BOS to Denver using Amazon Logistics: Reduced Cost = 24.77
# Warehouse_BOS to Denver using DHL: Reduced Cost = 32.19
# Warehouse_BOS to Denver using FedEx: Reduced Cost = 1.62
# Warehouse_BOS to Denver using LaserShip: Reduced Cost = 27.18
# Warehouse_BOS to Denver using OnTrac: Reduced Cost = 43.54
# Warehouse_BOS to Denver using UPS: Reduced Cost = 43.85
# Warehouse_BOS to Denver using USPS: Reduced Cost = 6.11
# Warehouse_BOS to Detroit using Amazon Logistics: Reduced Cost = 21.99
# Warehouse_BOS to Detroit using DHL: Reduced Cost = 34.66
# Warehouse_BOS to Detroit using FedEx: Reduced Cost = 0.00
# Warehouse_BOS to Detroit using LaserShip: Reduced Cost = 0.82
# Warehouse_BOS to Detroit using OnTrac: Reduced Cost = 47.03
# Warehouse_BOS to Detroit using UPS: Reduced Cost = 37.29
# Warehouse_BOS to Detroit using USPS: Reduced Cost = 23.35
# Warehouse_BOS to Houston using Amazon Logistics: Reduced Cost = 2.68
# Warehouse_BOS to Houston using DHL: Reduced Cost = 34.43
# Warehouse_BOS to Houston using FedEx: Reduced Cost = 38.21
# Warehouse_BOS to Houston using LaserShip: Reduced Cost = 1.21
# Warehouse_BOS to Houston using OnTrac: Reduced Cost = 0.00
# Warehouse_BOS to Houston using UPS: Reduced Cost = 582.55
# Warehouse_BOS to Houston using USPS: Reduced Cost = 22.16
# Warehouse_BOS to Los Angeles using Amazon Logistics: Reduced Cost = 1.83
# Warehouse_BOS to Los Angeles using DHL: Reduced Cost = 5.53
# Warehouse_BOS to Los Angeles using FedEx: Reduced Cost = 0.00
# Warehouse_BOS to Los Angeles using LaserShip: Reduced Cost = 2.78
# Warehouse_BOS to Los Angeles using OnTrac: Reduced Cost = 35.74
# Warehouse_BOS to Los Angeles using UPS: Reduced Cost = 31.18
# Warehouse_BOS to Los Angeles using USPS: Reduced Cost = 56.72
# Warehouse_BOS to Miami using Amazon Logistics: Reduced Cost = 12.18
# Warehouse_BOS to Miami using DHL: Reduced Cost = 27.45
# Warehouse_BOS to Miami using FedEx: Reduced Cost = 24.36
# Warehouse_BOS to Miami using LaserShip: Reduced Cost = 28.83
# Warehouse_BOS to Miami using OnTrac: Reduced Cost = 44.44
# Warehouse_BOS to Miami using UPS: Reduced Cost = 35.87
# Warehouse_BOS to Miami using USPS: Reduced Cost = 25.89
# Warehouse_BOS to Minneapolis using Amazon Logistics: Reduced Cost = 15.60
# Warehouse_BOS to Minneapolis using DHL: Reduced Cost = 39.34
# Warehouse_BOS to Minneapolis using FedEx: Reduced Cost = 0.00
# Warehouse_BOS to Minneapolis using LaserShip: Reduced Cost = 11.05
# Warehouse_BOS to Minneapolis using OnTrac: Reduced Cost = 34.01
# Warehouse_BOS to Minneapolis using UPS: Reduced Cost = 21.13
# Warehouse_BOS to Minneapolis using USPS: Reduced Cost = 13.78
# Warehouse_BOS to New York using Amazon Logistics: Reduced Cost = 59.50
# Warehouse_BOS to New York using DHL: Reduced Cost = 27.79
# Warehouse_BOS to New York using FedEx: Reduced Cost = 64.59
# Warehouse_BOS to New York using LaserShip: Reduced Cost = 13.93
# Warehouse_BOS to New York using OnTrac: Reduced Cost = 42.33
# Warehouse_BOS to New York using UPS: Reduced Cost = 3.49
# Warehouse_BOS to New York using USPS: Reduced Cost = 0.00
# Warehouse_BOS to Phoenix using Amazon Logistics: Reduced Cost = 10.32
# Warehouse_BOS to Phoenix using DHL: Reduced Cost = 38.64
# Warehouse_BOS to Phoenix using FedEx: Reduced Cost = 0.00
# Warehouse_BOS to Phoenix using LaserShip: Reduced Cost = 9.14
# Warehouse_BOS to Phoenix using OnTrac: Reduced Cost = 45.46
# Warehouse_BOS to Phoenix using UPS: Reduced Cost = 52.81
# Warehouse_BOS to Phoenix using USPS: Reduced Cost = 9.65
# Warehouse_BOS to Portland using Amazon Logistics: Reduced Cost = 15.27
# Warehouse_BOS to Portland using DHL: Reduced Cost = 88.33
# Warehouse_BOS to Portland using FedEx: Reduced Cost = 0.00
# Warehouse_BOS to Portland using LaserShip: Reduced Cost = 25.00
# Warehouse_BOS to Portland using OnTrac: Reduced Cost = 37.03
# Warehouse_BOS to Portland using UPS: Reduced Cost = 42.57
# Warehouse_BOS to Portland using USPS: Reduced Cost = 39.57
# Warehouse_BOS to San Francisco using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_BOS to San Francisco using DHL: Reduced Cost = 0.00
# Warehouse_BOS to San Francisco using FedEx: Reduced Cost = 33.82
# Warehouse_BOS to San Francisco using LaserShip: Reduced Cost = 30.74
# Warehouse_BOS to San Francisco using OnTrac: Reduced Cost = 6.64
# Warehouse_BOS to San Francisco using UPS: Reduced Cost = 0.00
# Warehouse_BOS to San Francisco using USPS: Reduced Cost = 66.83
# Warehouse_BOS to Seattle using Amazon Logistics: Reduced Cost = 3.60
# Warehouse_BOS to Seattle using DHL: Reduced Cost = 55.84
# Warehouse_BOS to Seattle using FedEx: Reduced Cost = 26.45
# Warehouse_BOS to Seattle using LaserShip: Reduced Cost = 4.12
# Warehouse_BOS to Seattle using OnTrac: Reduced Cost = 39.32
# Warehouse_BOS to Seattle using UPS: Reduced Cost = 14.42
# Warehouse_BOS to Seattle using USPS: Reduced Cost = 29.34
# Warehouse_CHI to Atlanta using Amazon Logistics: Reduced Cost = 15.67
# Warehouse_CHI to Atlanta using DHL: Reduced Cost = 38.43
# Warehouse_CHI to Atlanta using FedEx: Reduced Cost = 24.63
# Warehouse_CHI to Atlanta using LaserShip: Reduced Cost = 23.71
# Warehouse_CHI to Atlanta using OnTrac: Reduced Cost = 32.83
# Warehouse_CHI to Atlanta using UPS: Reduced Cost = 27.75
# Warehouse_CHI to Atlanta using USPS: Reduced Cost = 43.40
# Warehouse_CHI to Boston using Amazon Logistics: Reduced Cost = 5.80
# Warehouse_CHI to Boston using DHL: Reduced Cost = 86.24
# Warehouse_CHI to Boston using FedEx: Reduced Cost = 25.00
# Warehouse_CHI to Boston using LaserShip: Reduced Cost = 15.04
# Warehouse_CHI to Boston using OnTrac: Reduced Cost = 64.64
# Warehouse_CHI to Boston using UPS: Reduced Cost = 27.21
# Warehouse_CHI to Boston using USPS: Reduced Cost = 0.00
# Warehouse_CHI to Chicago using Amazon Logistics: Reduced Cost = 40.21
# Warehouse_CHI to Chicago using DHL: Reduced Cost = 20.55
# Warehouse_CHI to Chicago using FedEx: Reduced Cost = 6.69
# Warehouse_CHI to Chicago using LaserShip: Reduced Cost = 0.00
# Warehouse_CHI to Chicago using OnTrac: Reduced Cost = 18.98
# Warehouse_CHI to Chicago using UPS: Reduced Cost = 9.82
# Warehouse_CHI to Chicago using USPS: Reduced Cost = 35.69
# Warehouse_CHI to Dallas using Amazon Logistics: Reduced Cost = 19.64
# Warehouse_CHI to Dallas using DHL: Reduced Cost = 0.00
# Warehouse_CHI to Dallas using FedEx: Reduced Cost = 37.07
# Warehouse_CHI to Dallas using LaserShip: Reduced Cost = 1.00
# Warehouse_CHI to Dallas using OnTrac: Reduced Cost = 11.84
# Warehouse_CHI to Dallas using UPS: Reduced Cost = 30.28
# Warehouse_CHI to Dallas using USPS: Reduced Cost = 24.73
# Warehouse_CHI to Denver using Amazon Logistics: Reduced Cost = 9.47
# Warehouse_CHI to Denver using DHL: Reduced Cost = 26.59
# Warehouse_CHI to Denver using FedEx: Reduced Cost = 14.16
# Warehouse_CHI to Denver using LaserShip: Reduced Cost = 10.10
# Warehouse_CHI to Denver using OnTrac: Reduced Cost = 19.75
# Warehouse_CHI to Denver using UPS: Reduced Cost = 18.55
# Warehouse_CHI to Denver using USPS: Reduced Cost = 20.23
# Warehouse_CHI to Detroit using Amazon Logistics: Reduced Cost = 0.40
# Warehouse_CHI to Detroit using DHL: Reduced Cost = 0.00
# Warehouse_CHI to Detroit using FedEx: Reduced Cost = 0.87
# Warehouse_CHI to Detroit using LaserShip: Reduced Cost = 0.63
# Warehouse_CHI to Detroit using OnTrac: Reduced Cost = 2.67
# Warehouse_CHI to Detroit using UPS: Reduced Cost = 2.92
# Warehouse_CHI to Detroit using USPS: Reduced Cost = 3.42
# Warehouse_CHI to Houston using Amazon Logistics: Reduced Cost = 26.54
# Warehouse_CHI to Houston using DHL: Reduced Cost = 53.67
# Warehouse_CHI to Houston using FedEx: Reduced Cost = 14.08
# Warehouse_CHI to Houston using LaserShip: Reduced Cost = 28.13
# Warehouse_CHI to Houston using OnTrac: Reduced Cost = 57.13
# Warehouse_CHI to Houston using UPS: Reduced Cost = 29.16
# Warehouse_CHI to Houston using USPS: Reduced Cost = 42.94
# Warehouse_CHI to Los Angeles using Amazon Logistics: Reduced Cost = 7.95
# Warehouse_CHI to Los Angeles using DHL: Reduced Cost = 3.24
# Warehouse_CHI to Los Angeles using FedEx: Reduced Cost = 0.25
# Warehouse_CHI to Los Angeles using LaserShip: Reduced Cost = 1.00
# Warehouse_CHI to Los Angeles using OnTrac: Reduced Cost = 6.60
# Warehouse_CHI to Los Angeles using UPS: Reduced Cost = 30.16
# Warehouse_CHI to Los Angeles using USPS: Reduced Cost = 12.33
# Warehouse_CHI to Miami using Amazon Logistics: Reduced Cost = 13.19
# Warehouse_CHI to Miami using DHL: Reduced Cost = 0.95
# Warehouse_CHI to Miami using FedEx: Reduced Cost = 17.08
# Warehouse_CHI to Miami using LaserShip: Reduced Cost = 18.16
# Warehouse_CHI to Miami using OnTrac: Reduced Cost = 27.17
# Warehouse_CHI to Miami using UPS: Reduced Cost = 0.95
# Warehouse_CHI to Miami using USPS: Reduced Cost = 35.12
# Warehouse_CHI to Minneapolis using Amazon Logistics: Reduced Cost = 12.99
# Warehouse_CHI to Minneapolis using DHL: Reduced Cost = 31.17
# Warehouse_CHI to Minneapolis using FedEx: Reduced Cost = 14.53
# Warehouse_CHI to Minneapolis using LaserShip: Reduced Cost = 10.80
# Warehouse_CHI to Minneapolis using OnTrac: Reduced Cost = 2.90
# Warehouse_CHI to Minneapolis using UPS: Reduced Cost = 0.00
# Warehouse_CHI to Minneapolis using USPS: Reduced Cost = 31.23
# Warehouse_CHI to New York using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_CHI to New York using DHL: Reduced Cost = 13.20
# Warehouse_CHI to New York using FedEx: Reduced Cost = 33.19
# Warehouse_CHI to New York using LaserShip: Reduced Cost = 1.00
# Warehouse_CHI to New York using OnTrac: Reduced Cost = 50.71
# Warehouse_CHI to New York using UPS: Reduced Cost = 0.00
# Warehouse_CHI to New York using USPS: Reduced Cost = 10.36
# Warehouse_CHI to Phoenix using Amazon Logistics: Reduced Cost = 0.86
# Warehouse_CHI to Phoenix using DHL: Reduced Cost = 46.24
# Warehouse_CHI to Phoenix using FedEx: Reduced Cost = 0.38
# Warehouse_CHI to Phoenix using LaserShip: Reduced Cost = 22.24
# Warehouse_CHI to Phoenix using OnTrac: Reduced Cost = 30.88
# Warehouse_CHI to Phoenix using UPS: Reduced Cost = 0.38
# Warehouse_CHI to Phoenix using USPS: Reduced Cost = 0.38
# Warehouse_CHI to Portland using Amazon Logistics: Reduced Cost = 11.59
# Warehouse_CHI to Portland using DHL: Reduced Cost = 4.98
# Warehouse_CHI to Portland using FedEx: Reduced Cost = 3.56
# Warehouse_CHI to Portland using LaserShip: Reduced Cost = 14.14
# Warehouse_CHI to Portland using OnTrac: Reduced Cost = 0.30
# Warehouse_CHI to Portland using UPS: Reduced Cost = 57.66
# Warehouse_CHI to Portland using USPS: Reduced Cost = 31.35
# Warehouse_CHI to San Francisco using Amazon Logistics: Reduced Cost = 10.60
# Warehouse_CHI to San Francisco using DHL: Reduced Cost = 51.23
# Warehouse_CHI to San Francisco using FedEx: Reduced Cost = 25.77
# Warehouse_CHI to San Francisco using LaserShip: Reduced Cost = 9.70
# Warehouse_CHI to San Francisco using OnTrac: Reduced Cost = 13.18
# Warehouse_CHI to San Francisco using UPS: Reduced Cost = 0.00
# Warehouse_CHI to San Francisco using USPS: Reduced Cost = 3.52
# Warehouse_CHI to Seattle using Amazon Logistics: Reduced Cost = 35.08
# Warehouse_CHI to Seattle using DHL: Reduced Cost = 68.18
# Warehouse_CHI to Seattle using FedEx: Reduced Cost = 46.35
# Warehouse_CHI to Seattle using LaserShip: Reduced Cost = 8.57
# Warehouse_CHI to Seattle using OnTrac: Reduced Cost = 42.84
# Warehouse_CHI to Seattle using UPS: Reduced Cost = 43.46
# Warehouse_CHI to Seattle using USPS: Reduced Cost = 38.11
# Warehouse_DEN to Atlanta using Amazon Logistics: Reduced Cost = 15.30
# Warehouse_DEN to Atlanta using DHL: Reduced Cost = 70.04
# Warehouse_DEN to Atlanta using FedEx: Reduced Cost = 9.21
# Warehouse_DEN to Atlanta using LaserShip: Reduced Cost = 12.98
# Warehouse_DEN to Atlanta using OnTrac: Reduced Cost = 17.98
# Warehouse_DEN to Atlanta using UPS: Reduced Cost = 40.57
# Warehouse_DEN to Atlanta using USPS: Reduced Cost = 16.20
# Warehouse_DEN to Boston using Amazon Logistics: Reduced Cost = 19.43
# Warehouse_DEN to Boston using DHL: Reduced Cost = 48.96
# Warehouse_DEN to Boston using FedEx: Reduced Cost = 35.58
# Warehouse_DEN to Boston using LaserShip: Reduced Cost = 12.12
# Warehouse_DEN to Boston using OnTrac: Reduced Cost = 33.51
# Warehouse_DEN to Boston using UPS: Reduced Cost = 0.22
# Warehouse_DEN to Boston using USPS: Reduced Cost = 45.79
# Warehouse_DEN to Chicago using Amazon Logistics: Reduced Cost = 27.74
# Warehouse_DEN to Chicago using DHL: Reduced Cost = 53.58
# Warehouse_DEN to Chicago using FedEx: Reduced Cost = 26.16
# Warehouse_DEN to Chicago using LaserShip: Reduced Cost = 13.43
# Warehouse_DEN to Chicago using OnTrac: Reduced Cost = 43.91
# Warehouse_DEN to Chicago using UPS: Reduced Cost = 30.01
# Warehouse_DEN to Chicago using USPS: Reduced Cost = 38.59
# Warehouse_DEN to Dallas using Amazon Logistics: Reduced Cost = 31.27
# Warehouse_DEN to Dallas using DHL: Reduced Cost = 25.27
# Warehouse_DEN to Dallas using FedEx: Reduced Cost = 16.41
# Warehouse_DEN to Dallas using LaserShip: Reduced Cost = 2.81
# Warehouse_DEN to Dallas using OnTrac: Reduced Cost = 42.77
# Warehouse_DEN to Dallas using UPS: Reduced Cost = 30.89
# Warehouse_DEN to Dallas using USPS: Reduced Cost = 10.93
# Warehouse_DEN to Denver using Amazon Logistics: Reduced Cost = 2.22
# Warehouse_DEN to Denver using DHL: Reduced Cost = 29.28
# Warehouse_DEN to Denver using FedEx: Reduced Cost = 10.65
# Warehouse_DEN to Denver using LaserShip: Reduced Cost = 1.23
# Warehouse_DEN to Denver using OnTrac: Reduced Cost = 25.29
# Warehouse_DEN to Denver using UPS: Reduced Cost = 37.40
# Warehouse_DEN to Denver using USPS: Reduced Cost = 0.22
# Warehouse_DEN to Detroit using Amazon Logistics: Reduced Cost = 15.53
# Warehouse_DEN to Detroit using DHL: Reduced Cost = 0.22
# Warehouse_DEN to Detroit using FedEx: Reduced Cost = 31.94
# Warehouse_DEN to Detroit using LaserShip: Reduced Cost = 1.23
# Warehouse_DEN to Detroit using OnTrac: Reduced Cost = 82.34
# Warehouse_DEN to Detroit using UPS: Reduced Cost = 17.45
# Warehouse_DEN to Detroit using USPS: Reduced Cost = 49.72
# Warehouse_DEN to Houston using Amazon Logistics: Reduced Cost = 11.18
# Warehouse_DEN to Houston using DHL: Reduced Cost = 24.38
# Warehouse_DEN to Houston using FedEx: Reduced Cost = 43.13
# Warehouse_DEN to Houston using LaserShip: Reduced Cost = 30.02
# Warehouse_DEN to Houston using OnTrac: Reduced Cost = 36.66
# Warehouse_DEN to Houston using UPS: Reduced Cost = 39.50
# Warehouse_DEN to Houston using USPS: Reduced Cost = 0.22
# Warehouse_DEN to Los Angeles using Amazon Logistics: Reduced Cost = 14.24
# Warehouse_DEN to Los Angeles using DHL: Reduced Cost = 0.22
# Warehouse_DEN to Los Angeles using FedEx: Reduced Cost = 68.41
# Warehouse_DEN to Los Angeles using LaserShip: Reduced Cost = 8.60
# Warehouse_DEN to Los Angeles using OnTrac: Reduced Cost = 39.62
# Warehouse_DEN to Los Angeles using UPS: Reduced Cost = 34.10
# Warehouse_DEN to Los Angeles using USPS: Reduced Cost = 21.76
# Warehouse_DEN to Miami using Amazon Logistics: Reduced Cost = 18.07
# Warehouse_DEN to Miami using DHL: Reduced Cost = 42.17
# Warehouse_DEN to Miami using FedEx: Reduced Cost = 1.17
# Warehouse_DEN to Miami using LaserShip: Reduced Cost = 0.00
# Warehouse_DEN to Miami using OnTrac: Reduced Cost = 52.53
# Warehouse_DEN to Miami using UPS: Reduced Cost = 10.79
# Warehouse_DEN to Miami using USPS: Reduced Cost = 28.58
# Warehouse_DEN to Minneapolis using Amazon Logistics: Reduced Cost = 9.83
# Warehouse_DEN to Minneapolis using DHL: Reduced Cost = 19.10
# Warehouse_DEN to Minneapolis using FedEx: Reduced Cost = 21.17
# Warehouse_DEN to Minneapolis using LaserShip: Reduced Cost = 14.00
# Warehouse_DEN to Minneapolis using OnTrac: Reduced Cost = 30.02
# Warehouse_DEN to Minneapolis using UPS: Reduced Cost = 0.22
# Warehouse_DEN to Minneapolis using USPS: Reduced Cost = 50.21
# Warehouse_DEN to New York using Amazon Logistics: Reduced Cost = 8.90
# Warehouse_DEN to New York using DHL: Reduced Cost = 48.09
# Warehouse_DEN to New York using FedEx: Reduced Cost = 24.39
# Warehouse_DEN to New York using LaserShip: Reduced Cost = 13.87
# Warehouse_DEN to New York using OnTrac: Reduced Cost = 22.80
# Warehouse_DEN to New York using UPS: Reduced Cost = 19.59
# Warehouse_DEN to New York using USPS: Reduced Cost = 17.53
# Warehouse_DEN to Phoenix using Amazon Logistics: Reduced Cost = 10.33
# Warehouse_DEN to Phoenix using DHL: Reduced Cost = 26.42
# Warehouse_DEN to Phoenix using FedEx: Reduced Cost = 16.73
# Warehouse_DEN to Phoenix using LaserShip: Reduced Cost = 4.52
# Warehouse_DEN to Phoenix using OnTrac: Reduced Cost = 74.73
# Warehouse_DEN to Phoenix using UPS: Reduced Cost = 0.60
# Warehouse_DEN to Phoenix using USPS: Reduced Cost = 10.82
# Warehouse_DEN to Portland using Amazon Logistics: Reduced Cost = 0.00
# Warehouse_DEN to Portland using DHL: Reduced Cost = 0.22
# Warehouse_DEN to Portland using FedEx: Reduced Cost = 26.25
# Warehouse_DEN to Portland using LaserShip: Reduced Cost = 18.84
# Warehouse_DEN to Portland using OnTrac: Reduced Cost = 0.22
# Warehouse_DEN to Portland using UPS: Reduced Cost = 23.20
# Warehouse_DEN to Portland using USPS: Reduced Cost = 31.46
# Warehouse_DEN to San Francisco using Amazon Logistics: Reduced Cost = 4.05
# Warehouse_DEN to San Francisco using DHL: Reduced Cost = 37.06
# Warehouse_DEN to San Francisco using FedEx: Reduced Cost = 25.92
# Warehouse_DEN to San Francisco using LaserShip: Reduced Cost = 27.34
# Warehouse_DEN to San Francisco using OnTrac: Reduced Cost = 38.23
# Warehouse_DEN to San Francisco using UPS: Reduced Cost = 26.42
# Warehouse_DEN to San Francisco using USPS: Reduced Cost = 14.41
# Warehouse_DEN to Seattle using Amazon Logistics: Reduced Cost = 40.79
# Warehouse_DEN to Seattle using DHL: Reduced Cost = 3.34
# Warehouse_DEN to Seattle using FedEx: Reduced Cost = 27.17
# Warehouse_DEN to Seattle using LaserShip: Reduced Cost = 4.35
# Warehouse_DEN to Seattle using OnTrac: Reduced Cost = 29.18
# Warehouse_DEN to Seattle using UPS: Reduced Cost = 37.46
# Warehouse_DEN to Seattle using USPS: Reduced Cost = 59.66
# Warehouse_HOU to Atlanta using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_HOU to Atlanta using DHL: Reduced Cost = 23.91
# Warehouse_HOU to Atlanta using FedEx: Reduced Cost = 13.31
# Warehouse_HOU to Atlanta using LaserShip: Reduced Cost = 7.11
# Warehouse_HOU to Atlanta using OnTrac: Reduced Cost = 14.51
# Warehouse_HOU to Atlanta using UPS: Reduced Cost = 17.06
# Warehouse_HOU to Atlanta using USPS: Reduced Cost = 13.59
# Warehouse_HOU to Boston using Amazon Logistics: Reduced Cost = 15.28
# Warehouse_HOU to Boston using DHL: Reduced Cost = 44.97
# Warehouse_HOU to Boston using FedEx: Reduced Cost = 18.45
# Warehouse_HOU to Boston using LaserShip: Reduced Cost = 33.48
# Warehouse_HOU to Boston using OnTrac: Reduced Cost = 15.95
# Warehouse_HOU to Boston using UPS: Reduced Cost = 7.23
# Warehouse_HOU to Boston using USPS: Reduced Cost = 23.70
# Warehouse_HOU to Chicago using Amazon Logistics: Reduced Cost = 10.28
# Warehouse_HOU to Chicago using DHL: Reduced Cost = 40.12
# Warehouse_HOU to Chicago using FedEx: Reduced Cost = 1.53
# Warehouse_HOU to Chicago using LaserShip: Reduced Cost = 26.69
# Warehouse_HOU to Chicago using OnTrac: Reduced Cost = 21.59
# Warehouse_HOU to Chicago using UPS: Reduced Cost = 18.89
# Warehouse_HOU to Chicago using USPS: Reduced Cost = 30.94
# Warehouse_HOU to Dallas using Amazon Logistics: Reduced Cost = 20.54
# Warehouse_HOU to Dallas using DHL: Reduced Cost = 7.23
# Warehouse_HOU to Dallas using FedEx: Reduced Cost = 12.20
# Warehouse_HOU to Dallas using LaserShip: Reduced Cost = 12.26
# Warehouse_HOU to Dallas using OnTrac: Reduced Cost = 34.66
# Warehouse_HOU to Dallas using UPS: Reduced Cost = 20.55
# Warehouse_HOU to Dallas using USPS: Reduced Cost = 0.00
# Warehouse_HOU to Denver using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_HOU to Denver using DHL: Reduced Cost = 24.75
# Warehouse_HOU to Denver using FedEx: Reduced Cost = 14.83
# Warehouse_HOU to Denver using LaserShip: Reduced Cost = 10.93
# Warehouse_HOU to Denver using OnTrac: Reduced Cost = 21.02
# Warehouse_HOU to Denver using UPS: Reduced Cost = 19.79
# Warehouse_HOU to Denver using USPS: Reduced Cost = 0.00
# Warehouse_HOU to Detroit using Amazon Logistics: Reduced Cost = 16.18
# Warehouse_HOU to Detroit using DHL: Reduced Cost = 23.41
# Warehouse_HOU to Detroit using FedEx: Reduced Cost = 54.91
# Warehouse_HOU to Detroit using LaserShip: Reduced Cost = 27.61
# Warehouse_HOU to Detroit using OnTrac: Reduced Cost = 39.36
# Warehouse_HOU to Detroit using UPS: Reduced Cost = 158.02
# Warehouse_HOU to Detroit using USPS: Reduced Cost = 11.26
# Warehouse_HOU to Houston using Amazon Logistics: Reduced Cost = 9.73
# Warehouse_HOU to Houston using DHL: Reduced Cost = 0.00
# Warehouse_HOU to Houston using FedEx: Reduced Cost = 0.00
# Warehouse_HOU to Houston using LaserShip: Reduced Cost = 15.06
# Warehouse_HOU to Houston using OnTrac: Reduced Cost = 14.87
# Warehouse_HOU to Houston using UPS: Reduced Cost = 17.91
# Warehouse_HOU to Houston using USPS: Reduced Cost = 18.10
# Warehouse_HOU to Los Angeles using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_HOU to Los Angeles using DHL: Reduced Cost = 22.93
# Warehouse_HOU to Los Angeles using FedEx: Reduced Cost = 0.00
# Warehouse_HOU to Los Angeles using LaserShip: Reduced Cost = 13.55
# Warehouse_HOU to Los Angeles using OnTrac: Reduced Cost = 47.34
# Warehouse_HOU to Los Angeles using UPS: Reduced Cost = 38.66
# Warehouse_HOU to Los Angeles using USPS: Reduced Cost = 23.06
# Warehouse_HOU to Miami using Amazon Logistics: Reduced Cost = 30.86
# Warehouse_HOU to Miami using DHL: Reduced Cost = 44.85
# Warehouse_HOU to Miami using FedEx: Reduced Cost = 23.03
# Warehouse_HOU to Miami using LaserShip: Reduced Cost = 14.35
# Warehouse_HOU to Miami using OnTrac: Reduced Cost = 20.92
# Warehouse_HOU to Miami using UPS: Reduced Cost = 28.61
# Warehouse_HOU to Miami using USPS: Reduced Cost = 22.11
# Warehouse_HOU to Minneapolis using Amazon Logistics: Reduced Cost = 26.32
# Warehouse_HOU to Minneapolis using DHL: Reduced Cost = 24.78
# Warehouse_HOU to Minneapolis using FedEx: Reduced Cost = 11.00
# Warehouse_HOU to Minneapolis using LaserShip: Reduced Cost = 1.00
# Warehouse_HOU to Minneapolis using OnTrac: Reduced Cost = 27.24
# Warehouse_HOU to Minneapolis using UPS: Reduced Cost = 39.04
# Warehouse_HOU to Minneapolis using USPS: Reduced Cost = 26.18
# Warehouse_HOU to New York using Amazon Logistics: Reduced Cost = 15.92
# Warehouse_HOU to New York using DHL: Reduced Cost = 37.19
# Warehouse_HOU to New York using FedEx: Reduced Cost = 23.91
# Warehouse_HOU to New York using LaserShip: Reduced Cost = 26.84
# Warehouse_HOU to New York using OnTrac: Reduced Cost = 15.12
# Warehouse_HOU to New York using UPS: Reduced Cost = 53.73
# Warehouse_HOU to New York using USPS: Reduced Cost = 25.37
# Warehouse_HOU to Phoenix using Amazon Logistics: Reduced Cost = 11.28
# Warehouse_HOU to Phoenix using DHL: Reduced Cost = 44.49
# Warehouse_HOU to Phoenix using FedEx: Reduced Cost = 44.08
# Warehouse_HOU to Phoenix using LaserShip: Reduced Cost = 7.72
# Warehouse_HOU to Phoenix using OnTrac: Reduced Cost = 28.29
# Warehouse_HOU to Phoenix using UPS: Reduced Cost = 28.97
# Warehouse_HOU to Phoenix using USPS: Reduced Cost = 28.87
# Warehouse_HOU to Portland using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_HOU to Portland using DHL: Reduced Cost = 56.85
# Warehouse_HOU to Portland using FedEx: Reduced Cost = 11.62
# Warehouse_HOU to Portland using LaserShip: Reduced Cost = 20.04
# Warehouse_HOU to Portland using OnTrac: Reduced Cost = 0.00
# Warehouse_HOU to Portland using UPS: Reduced Cost = 44.86
# Warehouse_HOU to Portland using USPS: Reduced Cost = 17.69
# Warehouse_HOU to San Francisco using Amazon Logistics: Reduced Cost = 5.36
# Warehouse_HOU to San Francisco using DHL: Reduced Cost = 0.00
# Warehouse_HOU to San Francisco using FedEx: Reduced Cost = 20.49
# Warehouse_HOU to San Francisco using LaserShip: Reduced Cost = 9.99
# Warehouse_HOU to San Francisco using OnTrac: Reduced Cost = 40.15
# Warehouse_HOU to San Francisco using UPS: Reduced Cost = 21.79
# Warehouse_HOU to San Francisco using USPS: Reduced Cost = 26.10
# Warehouse_HOU to Seattle using Amazon Logistics: Reduced Cost = 39.50
# Warehouse_HOU to Seattle using DHL: Reduced Cost = 56.47
# Warehouse_HOU to Seattle using FedEx: Reduced Cost = 35.46
# Warehouse_HOU to Seattle using LaserShip: Reduced Cost = 49.20
# Warehouse_HOU to Seattle using OnTrac: Reduced Cost = 15.63
# Warehouse_HOU to Seattle using UPS: Reduced Cost = 5.92
# Warehouse_HOU to Seattle using USPS: Reduced Cost = 3.12
# Warehouse_LA to Atlanta using Amazon Logistics: Reduced Cost = 19.04
# Warehouse_LA to Atlanta using DHL: Reduced Cost = 29.05
# Warehouse_LA to Atlanta using FedEx: Reduced Cost = 24.60
# Warehouse_LA to Atlanta using LaserShip: Reduced Cost = 22.67
# Warehouse_LA to Atlanta using OnTrac: Reduced Cost = 0.00
# Warehouse_LA to Atlanta using UPS: Reduced Cost = 15.86
# Warehouse_LA to Atlanta using USPS: Reduced Cost = 43.17
# Warehouse_LA to Boston using Amazon Logistics: Reduced Cost = 14.12
# Warehouse_LA to Boston using DHL: Reduced Cost = 36.63
# Warehouse_LA to Boston using FedEx: Reduced Cost = 0.00
# Warehouse_LA to Boston using LaserShip: Reduced Cost = 0.35
# Warehouse_LA to Boston using OnTrac: Reduced Cost = 7.71
# Warehouse_LA to Boston using UPS: Reduced Cost = 23.98
# Warehouse_LA to Boston using USPS: Reduced Cost = 24.10
# Warehouse_LA to Chicago using Amazon Logistics: Reduced Cost = 12.76
# Warehouse_LA to Chicago using DHL: Reduced Cost = 37.36
# Warehouse_LA to Chicago using FedEx: Reduced Cost = 12.54
# Warehouse_LA to Chicago using LaserShip: Reduced Cost = 20.89
# Warehouse_LA to Chicago using OnTrac: Reduced Cost = 15.78
# Warehouse_LA to Chicago using UPS: Reduced Cost = 40.01
# Warehouse_LA to Chicago using USPS: Reduced Cost = 32.74
# Warehouse_LA to Dallas using Amazon Logistics: Reduced Cost = 13.21
# Warehouse_LA to Dallas using DHL: Reduced Cost = 47.29
# Warehouse_LA to Dallas using FedEx: Reduced Cost = 18.87
# Warehouse_LA to Dallas using LaserShip: Reduced Cost = 16.22
# Warehouse_LA to Dallas using OnTrac: Reduced Cost = 28.76
# Warehouse_LA to Dallas using UPS: Reduced Cost = 35.64
# Warehouse_LA to Dallas using USPS: Reduced Cost = 25.85
# Warehouse_LA to Denver using Amazon Logistics: Reduced Cost = 12.32
# Warehouse_LA to Denver using DHL: Reduced Cost = 64.56
# Warehouse_LA to Denver using FedEx: Reduced Cost = 36.27
# Warehouse_LA to Denver using LaserShip: Reduced Cost = 13.51
# Warehouse_LA to Denver using OnTrac: Reduced Cost = 21.74
# Warehouse_LA to Denver using UPS: Reduced Cost = 18.43
# Warehouse_LA to Denver using USPS: Reduced Cost = 32.62
# Warehouse_LA to Detroit using Amazon Logistics: Reduced Cost = 1.49
# Warehouse_LA to Detroit using DHL: Reduced Cost = 11.03
# Warehouse_LA to Detroit using FedEx: Reduced Cost = 23.56
# Warehouse_LA to Detroit using LaserShip: Reduced Cost = 6.01
# Warehouse_LA to Detroit using OnTrac: Reduced Cost = 0.00
# Warehouse_LA to Detroit using UPS: Reduced Cost = 13.58
# Warehouse_LA to Detroit using USPS: Reduced Cost = 40.61
# Warehouse_LA to Houston using Amazon Logistics: Reduced Cost = 19.55
# Warehouse_LA to Houston using DHL: Reduced Cost = 22.84
# Warehouse_LA to Houston using FedEx: Reduced Cost = 31.72
# Warehouse_LA to Houston using LaserShip: Reduced Cost = 19.38
# Warehouse_LA to Houston using OnTrac: Reduced Cost = 7.85
# Warehouse_LA to Houston using UPS: Reduced Cost = 0.00
# Warehouse_LA to Houston using USPS: Reduced Cost = 19.02
# Warehouse_LA to Los Angeles using Amazon Logistics: Reduced Cost = 35.46
# Warehouse_LA to Los Angeles using DHL: Reduced Cost = 32.84
# Warehouse_LA to Los Angeles using FedEx: Reduced Cost = 23.36
# Warehouse_LA to Los Angeles using LaserShip: Reduced Cost = 16.19
# Warehouse_LA to Los Angeles using OnTrac: Reduced Cost = 38.63
# Warehouse_LA to Los Angeles using UPS: Reduced Cost = 25.56
# Warehouse_LA to Los Angeles using USPS: Reduced Cost = 45.70
# Warehouse_LA to Miami using Amazon Logistics: Reduced Cost = 18.01
# Warehouse_LA to Miami using DHL: Reduced Cost = 17.62
# Warehouse_LA to Miami using FedEx: Reduced Cost = 0.95
# Warehouse_LA to Miami using LaserShip: Reduced Cost = 17.58
# Warehouse_LA to Miami using OnTrac: Reduced Cost = 39.15
# Warehouse_LA to Miami using UPS: Reduced Cost = 10.76
# Warehouse_LA to Miami using USPS: Reduced Cost = 15.64
# Warehouse_LA to Minneapolis using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_LA to Minneapolis using DHL: Reduced Cost = 0.00
# Warehouse_LA to Minneapolis using FedEx: Reduced Cost = 18.53
# Warehouse_LA to Minneapolis using LaserShip: Reduced Cost = 15.01
# Warehouse_LA to Minneapolis using OnTrac: Reduced Cost = 59.57
# Warehouse_LA to Minneapolis using UPS: Reduced Cost = 38.59
# Warehouse_LA to Minneapolis using USPS: Reduced Cost = 37.23
# Warehouse_LA to New York using Amazon Logistics: Reduced Cost = 31.35
# Warehouse_LA to New York using DHL: Reduced Cost = 23.13
# Warehouse_LA to New York using FedEx: Reduced Cost = 32.77
# Warehouse_LA to New York using LaserShip: Reduced Cost = 18.25
# Warehouse_LA to New York using OnTrac: Reduced Cost = 20.71
# Warehouse_LA to New York using UPS: Reduced Cost = 19.54
# Warehouse_LA to New York using USPS: Reduced Cost = 17.76
# Warehouse_LA to Phoenix using Amazon Logistics: Reduced Cost = 2.15
# Warehouse_LA to Phoenix using DHL: Reduced Cost = 12.41
# Warehouse_LA to Phoenix using FedEx: Reduced Cost = 0.38
# Warehouse_LA to Phoenix using LaserShip: Reduced Cost = 3.65
# Warehouse_LA to Phoenix using OnTrac: Reduced Cost = 4.94
# Warehouse_LA to Phoenix using UPS: Reduced Cost = 4.89
# Warehouse_LA to Phoenix using USPS: Reduced Cost = 2.11
# Warehouse_LA to Portland using Amazon Logistics: Reduced Cost = 20.87
# Warehouse_LA to Portland using DHL: Reduced Cost = 64.11
# Warehouse_LA to Portland using FedEx: Reduced Cost = 21.86
# Warehouse_LA to Portland using LaserShip: Reduced Cost = 8.90
# Warehouse_LA to Portland using OnTrac: Reduced Cost = 34.17
# Warehouse_LA to Portland using UPS: Reduced Cost = 42.27
# Warehouse_LA to Portland using USPS: Reduced Cost = 13.73
# Warehouse_LA to San Francisco using Amazon Logistics: Reduced Cost = 18.87
# Warehouse_LA to San Francisco using DHL: Reduced Cost = 24.76
# Warehouse_LA to San Francisco using FedEx: Reduced Cost = 8.46
# Warehouse_LA to San Francisco using LaserShip: Reduced Cost = 70.66
# Warehouse_LA to San Francisco using OnTrac: Reduced Cost = 36.58
# Warehouse_LA to San Francisco using UPS: Reduced Cost = 16.71
# Warehouse_LA to San Francisco using USPS: Reduced Cost = 23.81
# Warehouse_LA to Seattle using Amazon Logistics: Reduced Cost = 7.83
# Warehouse_LA to Seattle using DHL: Reduced Cost = 3.12
# Warehouse_LA to Seattle using FedEx: Reduced Cost = 18.74
# Warehouse_LA to Seattle using LaserShip: Reduced Cost = 15.11
# Warehouse_LA to Seattle using OnTrac: Reduced Cost = 26.92
# Warehouse_LA to Seattle using UPS: Reduced Cost = 24.41
# Warehouse_LA to Seattle using USPS: Reduced Cost = 23.54
# Warehouse_MIA to Atlanta using Amazon Logistics: Reduced Cost = 9.43
# Warehouse_MIA to Atlanta using DHL: Reduced Cost = 31.26
# Warehouse_MIA to Atlanta using FedEx: Reduced Cost = 16.90
# Warehouse_MIA to Atlanta using LaserShip: Reduced Cost = 1.00
# Warehouse_MIA to Atlanta using OnTrac: Reduced Cost = 26.92
# Warehouse_MIA to Atlanta using UPS: Reduced Cost = 0.00
# Warehouse_MIA to Atlanta using USPS: Reduced Cost = 19.98
# Warehouse_MIA to Boston using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_MIA to Boston using DHL: Reduced Cost = 47.09
# Warehouse_MIA to Boston using FedEx: Reduced Cost = 40.25
# Warehouse_MIA to Boston using LaserShip: Reduced Cost = 1.00
# Warehouse_MIA to Boston using OnTrac: Reduced Cost = 51.60
# Warehouse_MIA to Boston using UPS: Reduced Cost = 14.21
# Warehouse_MIA to Boston using USPS: Reduced Cost = 28.79
# Warehouse_MIA to Chicago using Amazon Logistics: Reduced Cost = 18.50
# Warehouse_MIA to Chicago using DHL: Reduced Cost = 24.14
# Warehouse_MIA to Chicago using FedEx: Reduced Cost = 37.58
# Warehouse_MIA to Chicago using LaserShip: Reduced Cost = 8.73
# Warehouse_MIA to Chicago using OnTrac: Reduced Cost = 14.44
# Warehouse_MIA to Chicago using UPS: Reduced Cost = 36.73
# Warehouse_MIA to Chicago using USPS: Reduced Cost = 22.55
# Warehouse_MIA to Dallas using Amazon Logistics: Reduced Cost = 16.27
# Warehouse_MIA to Dallas using DHL: Reduced Cost = 0.00
# Warehouse_MIA to Dallas using FedEx: Reduced Cost = 2.24
# Warehouse_MIA to Dallas using LaserShip: Reduced Cost = 1.00
# Warehouse_MIA to Dallas using OnTrac: Reduced Cost = 80.61
# Warehouse_MIA to Dallas using UPS: Reduced Cost = 27.07
# Warehouse_MIA to Dallas using USPS: Reduced Cost = 41.88
# Warehouse_MIA to Denver using Amazon Logistics: Reduced Cost = 8.86
# Warehouse_MIA to Denver using DHL: Reduced Cost = 0.00
# Warehouse_MIA to Denver using FedEx: Reduced Cost = 13.39
# Warehouse_MIA to Denver using LaserShip: Reduced Cost = 17.72
# Warehouse_MIA to Denver using OnTrac: Reduced Cost = 7.64
# Warehouse_MIA to Denver using UPS: Reduced Cost = 15.81
# Warehouse_MIA to Denver using USPS: Reduced Cost = 29.33
# Warehouse_MIA to Detroit using Amazon Logistics: Reduced Cost = 15.68
# Warehouse_MIA to Detroit using DHL: Reduced Cost = 31.84
# Warehouse_MIA to Detroit using FedEx: Reduced Cost = 0.00
# Warehouse_MIA to Detroit using LaserShip: Reduced Cost = 16.75
# Warehouse_MIA to Detroit using OnTrac: Reduced Cost = 34.94
# Warehouse_MIA to Detroit using UPS: Reduced Cost = 34.91
# Warehouse_MIA to Detroit using USPS: Reduced Cost = 20.53
# Warehouse_MIA to Houston using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_MIA to Houston using DHL: Reduced Cost = 0.00
# Warehouse_MIA to Houston using FedEx: Reduced Cost = 0.04
# Warehouse_MIA to Houston using LaserShip: Reduced Cost = 8.89
# Warehouse_MIA to Houston using OnTrac: Reduced Cost = 15.81
# Warehouse_MIA to Houston using UPS: Reduced Cost = 28.45
# Warehouse_MIA to Houston using USPS: Reduced Cost = 41.27
# Warehouse_MIA to Los Angeles using Amazon Logistics: Reduced Cost = 21.88
# Warehouse_MIA to Los Angeles using DHL: Reduced Cost = 38.64
# Warehouse_MIA to Los Angeles using FedEx: Reduced Cost = 16.25
# Warehouse_MIA to Los Angeles using LaserShip: Reduced Cost = 9.19
# Warehouse_MIA to Los Angeles using OnTrac: Reduced Cost = 32.19
# Warehouse_MIA to Los Angeles using UPS: Reduced Cost = 30.10
# Warehouse_MIA to Los Angeles using USPS: Reduced Cost = 0.00
# Warehouse_MIA to Miami using Amazon Logistics: Reduced Cost = 1.42
# Warehouse_MIA to Miami using DHL: Reduced Cost = 0.95
# Warehouse_MIA to Miami using FedEx: Reduced Cost = 24.17
# Warehouse_MIA to Miami using LaserShip: Reduced Cost = 12.60
# Warehouse_MIA to Miami using OnTrac: Reduced Cost = 0.95
# Warehouse_MIA to Miami using UPS: Reduced Cost = 27.34
# Warehouse_MIA to Miami using USPS: Reduced Cost = 0.95
# Warehouse_MIA to Minneapolis using Amazon Logistics: Reduced Cost = 21.48
# Warehouse_MIA to Minneapolis using DHL: Reduced Cost = 50.95
# Warehouse_MIA to Minneapolis using FedEx: Reduced Cost = 19.00
# Warehouse_MIA to Minneapolis using LaserShip: Reduced Cost = 24.21
# Warehouse_MIA to Minneapolis using OnTrac: Reduced Cost = 53.01
# Warehouse_MIA to Minneapolis using UPS: Reduced Cost = 0.00
# Warehouse_MIA to Minneapolis using USPS: Reduced Cost = 29.95
# Warehouse_MIA to New York using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_MIA to New York using DHL: Reduced Cost = 32.12
# Warehouse_MIA to New York using FedEx: Reduced Cost = 37.36
# Warehouse_MIA to New York using LaserShip: Reduced Cost = 11.96
# Warehouse_MIA to New York using OnTrac: Reduced Cost = 41.24
# Warehouse_MIA to New York using UPS: Reduced Cost = 25.74
# Warehouse_MIA to New York using USPS: Reduced Cost = 17.36
# Warehouse_MIA to Phoenix using Amazon Logistics: Reduced Cost = 14.00
# Warehouse_MIA to Phoenix using DHL: Reduced Cost = 51.02
# Warehouse_MIA to Phoenix using FedEx: Reduced Cost = 9.40
# Warehouse_MIA to Phoenix using LaserShip: Reduced Cost = 26.68
# Warehouse_MIA to Phoenix using OnTrac: Reduced Cost = 8.33
# Warehouse_MIA to Phoenix using UPS: Reduced Cost = 8.49
# Warehouse_MIA to Phoenix using USPS: Reduced Cost = 44.90
# Warehouse_MIA to Portland using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_MIA to Portland using DHL: Reduced Cost = 49.21
# Warehouse_MIA to Portland using FedEx: Reduced Cost = 25.57
# Warehouse_MIA to Portland using LaserShip: Reduced Cost = 6.29
# Warehouse_MIA to Portland using OnTrac: Reduced Cost = 47.11
# Warehouse_MIA to Portland using UPS: Reduced Cost = 31.02
# Warehouse_MIA to Portland using USPS: Reduced Cost = 18.97
# Warehouse_MIA to San Francisco using Amazon Logistics: Reduced Cost = 13.98
# Warehouse_MIA to San Francisco using DHL: Reduced Cost = 39.35
# Warehouse_MIA to San Francisco using FedEx: Reduced Cost = 0.00
# Warehouse_MIA to San Francisco using LaserShip: Reduced Cost = 20.35
# Warehouse_MIA to San Francisco using OnTrac: Reduced Cost = 15.88
# Warehouse_MIA to San Francisco using UPS: Reduced Cost = 27.94
# Warehouse_MIA to San Francisco using USPS: Reduced Cost = 0.00
# Warehouse_MIA to Seattle using Amazon Logistics: Reduced Cost = 14.46
# Warehouse_MIA to Seattle using DHL: Reduced Cost = 41.41
# Warehouse_MIA to Seattle using FedEx: Reduced Cost = 3.12
# Warehouse_MIA to Seattle using LaserShip: Reduced Cost = 12.01
# Warehouse_MIA to Seattle using OnTrac: Reduced Cost = 3.01
# Warehouse_MIA to Seattle using UPS: Reduced Cost = 32.93
# Warehouse_MIA to Seattle using USPS: Reduced Cost = 3.12
# Warehouse_NYC to Atlanta using Amazon Logistics: Reduced Cost = 1.72
# Warehouse_NYC to Atlanta using DHL: Reduced Cost = 1.25
# Warehouse_NYC to Atlanta using FedEx: Reduced Cost = 13.78
# Warehouse_NYC to Atlanta using LaserShip: Reduced Cost = 8.41
# Warehouse_NYC to Atlanta using OnTrac: Reduced Cost = 19.79
# Warehouse_NYC to Atlanta using UPS: Reduced Cost = 12.94
# Warehouse_NYC to Atlanta using USPS: Reduced Cost = 19.33
# Warehouse_NYC to Boston using Amazon Logistics: Reduced Cost = 0.00
# Warehouse_NYC to Boston using DHL: Reduced Cost = 1.25
# Warehouse_NYC to Boston using FedEx: Reduced Cost = 1.25
# Warehouse_NYC to Boston using LaserShip: Reduced Cost = 2.25
# Warehouse_NYC to Boston using OnTrac: Reduced Cost = 3.37
# Warehouse_NYC to Boston using UPS: Reduced Cost = 0.00
# Warehouse_NYC to Boston using USPS: Reduced Cost = 6.30
# Warehouse_NYC to Chicago using Amazon Logistics: Reduced Cost = 3.25
# Warehouse_NYC to Chicago using DHL: Reduced Cost = 23.50
# Warehouse_NYC to Chicago using FedEx: Reduced Cost = 18.82
# Warehouse_NYC to Chicago using LaserShip: Reduced Cost = 16.46
# Warehouse_NYC to Chicago using OnTrac: Reduced Cost = 18.80
# Warehouse_NYC to Chicago using UPS: Reduced Cost = 15.06
# Warehouse_NYC to Chicago using USPS: Reduced Cost = 16.89
# Warehouse_NYC to Dallas using Amazon Logistics: Reduced Cost = 14.34
# Warehouse_NYC to Dallas using DHL: Reduced Cost = 28.22
# Warehouse_NYC to Dallas using FedEx: Reduced Cost = 11.45
# ...
# Warehouse_NYC to Los Angeles using LaserShip: Reduced Cost = 16.41
# Warehouse_NYC to Los Angeles using OnTrac: Reduced Cost = 17.30
# Warehouse_NYC to Los Angeles using UPS: Reduced Cost = 31.77
# Warehouse_NYC to Los Angeles using USPS: Reduced Cost = 14.29
# Warehouse_NYC to Miami using Amazon Logistics: Reduced Cost = 11.08
# Warehouse_NYC to Miami using DHL: Reduced Cost = 62.49
# Warehouse_NYC to Miami using FedEx: Reduced Cost = 17.04
# Warehouse_NYC to Miami using LaserShip: Reduced Cost = 23.25
# Warehouse_NYC to Miami using OnTrac: Reduced Cost = 2.20
# Warehouse_NYC to Miami using UPS: Reduced Cost = 3.84
# Warehouse_NYC to Miami using USPS: Reduced Cost = 25.28
# Warehouse_NYC to Minneapolis using Amazon Logistics: Reduced Cost = 13.39
# Warehouse_NYC to Minneapolis using DHL: Reduced Cost = 12.13
# Warehouse_NYC to Minneapolis using FedEx: Reduced Cost = 25.28
# Warehouse_NYC to Minneapolis using LaserShip: Reduced Cost = 2.25
# Warehouse_NYC to Minneapolis using OnTrac: Reduced Cost = 11.67
# Warehouse_NYC to Minneapolis using UPS: Reduced Cost = 38.90
# Warehouse_NYC to Minneapolis using USPS: Reduced Cost = 20.26
# Warehouse_NYC to New York using Amazon Logistics: Reduced Cost = 1.72
# Warehouse_NYC to New York using DHL: Reduced Cost = 54.72
# Warehouse_NYC to New York using FedEx: Reduced Cost = 1.25
# Warehouse_NYC to New York using LaserShip: Reduced Cost = 14.15
# Warehouse_NYC to New York using OnTrac: Reduced Cost = 1.25
# Warehouse_NYC to New York using UPS: Reduced Cost = 24.07
# Warehouse_NYC to New York using USPS: Reduced Cost = 1.25
# Warehouse_NYC to Phoenix using Amazon Logistics: Reduced Cost = 22.42
# Warehouse_NYC to Phoenix using DHL: Reduced Cost = 24.17
# Warehouse_NYC to Phoenix using FedEx: Reduced Cost = 46.13
# Warehouse_NYC to Phoenix using LaserShip: Reduced Cost = 2.64
# Warehouse_NYC to Phoenix using OnTrac: Reduced Cost = 20.21
# Warehouse_NYC to Phoenix using UPS: Reduced Cost = 37.00
# Warehouse_NYC to Phoenix using USPS: Reduced Cost = 30.00
# Warehouse_NYC to Portland using Amazon Logistics: Reduced Cost = 61.02
# Warehouse_NYC to Portland using DHL: Reduced Cost = 47.58
# Warehouse_NYC to Portland using FedEx: Reduced Cost = 47.91
# Warehouse_NYC to Portland using LaserShip: Reduced Cost = 18.98
# Warehouse_NYC to Portland using OnTrac: Reduced Cost = 21.12
# Warehouse_NYC to Portland using UPS: Reduced Cost = 20.18
# Warehouse_NYC to Portland using USPS: Reduced Cost = 34.60
# Warehouse_NYC to San Francisco using Amazon Logistics: Reduced Cost = 5.46
# Warehouse_NYC to San Francisco using DHL: Reduced Cost = 88.36
# Warehouse_NYC to San Francisco using FedEx: Reduced Cost = 22.59
# Warehouse_NYC to San Francisco using LaserShip: Reduced Cost = 17.14
# Warehouse_NYC to San Francisco using OnTrac: Reduced Cost = 1.25
# Warehouse_NYC to San Francisco using UPS: Reduced Cost = 43.98
# Warehouse_NYC to San Francisco using USPS: Reduced Cost = 47.47
# Warehouse_NYC to Seattle using Amazon Logistics: Reduced Cost = 4.84
# Warehouse_NYC to Seattle using DHL: Reduced Cost = 33.15
# Warehouse_NYC to Seattle using FedEx: Reduced Cost = 17.05
# Warehouse_NYC to Seattle using LaserShip: Reduced Cost = 13.83
# Warehouse_NYC to Seattle using OnTrac: Reduced Cost = 18.57
# Warehouse_NYC to Seattle using UPS: Reduced Cost = 4.37
# Warehouse_NYC to Seattle using USPS: Reduced Cost = 35.28
# Warehouse_SEA to Atlanta using Amazon Logistics: Reduced Cost = 4.66
# Warehouse_SEA to Atlanta using DHL: Reduced Cost = 22.16
# Warehouse_SEA to Atlanta using FedEx: Reduced Cost = 23.09
# Warehouse_SEA to Atlanta using LaserShip: Reduced Cost = 1.00
# Warehouse_SEA to Atlanta using OnTrac: Reduced Cost = 32.81
# Warehouse_SEA to Atlanta using UPS: Reduced Cost = 21.88
# Warehouse_SEA to Atlanta using USPS: Reduced Cost = 0.00
# Warehouse_SEA to Boston using Amazon Logistics: Reduced Cost = 34.21
# Warehouse_SEA to Boston using DHL: Reduced Cost = 69.32
# Warehouse_SEA to Boston using FedEx: Reduced Cost = 30.29
# Warehouse_SEA to Boston using LaserShip: Reduced Cost = 18.89
# Warehouse_SEA to Boston using OnTrac: Reduced Cost = 31.49
# Warehouse_SEA to Boston using UPS: Reduced Cost = 0.00
# Warehouse_SEA to Boston using USPS: Reduced Cost = 0.00
# Warehouse_SEA to Chicago using Amazon Logistics: Reduced Cost = 14.30
# Warehouse_SEA to Chicago using DHL: Reduced Cost = 38.51
# Warehouse_SEA to Chicago using FedEx: Reduced Cost = 29.83
# Warehouse_SEA to Chicago using LaserShip: Reduced Cost = 2.53
# Warehouse_SEA to Chicago using OnTrac: Reduced Cost = 63.83
# Warehouse_SEA to Chicago using UPS: Reduced Cost = 29.00
# Warehouse_SEA to Chicago using USPS: Reduced Cost = 28.43
# Warehouse_SEA to Dallas using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_SEA to Dallas using DHL: Reduced Cost = 30.34
# Warehouse_SEA to Dallas using FedEx: Reduced Cost = 1.36
# Warehouse_SEA to Dallas using LaserShip: Reduced Cost = 1.00
# Warehouse_SEA to Dallas using OnTrac: Reduced Cost = 43.02
# Warehouse_SEA to Dallas using UPS: Reduced Cost = 24.44
# Warehouse_SEA to Dallas using USPS: Reduced Cost = 36.22
# Warehouse_SEA to Denver using Amazon Logistics: Reduced Cost = 48.14
# Warehouse_SEA to Denver using DHL: Reduced Cost = 41.43
# Warehouse_SEA to Denver using FedEx: Reduced Cost = 32.52
# Warehouse_SEA to Denver using LaserShip: Reduced Cost = 14.89
# Warehouse_SEA to Denver using OnTrac: Reduced Cost = 28.14
# Warehouse_SEA to Denver using UPS: Reduced Cost = 25.55
# Warehouse_SEA to Denver using USPS: Reduced Cost = 11.54
# Warehouse_SEA to Detroit using Amazon Logistics: Reduced Cost = 17.74
# Warehouse_SEA to Detroit using DHL: Reduced Cost = 35.58
# Warehouse_SEA to Detroit using FedEx: Reduced Cost = 26.98
# Warehouse_SEA to Detroit using LaserShip: Reduced Cost = 22.71
# Warehouse_SEA to Detroit using OnTrac: Reduced Cost = 5.41
# Warehouse_SEA to Detroit using UPS: Reduced Cost = 19.24
# Warehouse_SEA to Detroit using USPS: Reduced Cost = 26.95
# Warehouse_SEA to Houston using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_SEA to Houston using DHL: Reduced Cost = 34.04
# Warehouse_SEA to Houston using FedEx: Reduced Cost = 19.62
# Warehouse_SEA to Houston using LaserShip: Reduced Cost = 24.40
# Warehouse_SEA to Houston using OnTrac: Reduced Cost = 41.64
# Warehouse_SEA to Houston using UPS: Reduced Cost = 3.09
# Warehouse_SEA to Houston using USPS: Reduced Cost = 11.73
# Warehouse_SEA to Los Angeles using Amazon Logistics: Reduced Cost = 38.22
# Warehouse_SEA to Los Angeles using DHL: Reduced Cost = 39.13
# Warehouse_SEA to Los Angeles using FedEx: Reduced Cost = 25.96
# Warehouse_SEA to Los Angeles using LaserShip: Reduced Cost = 4.16
# Warehouse_SEA to Los Angeles using OnTrac: Reduced Cost = 37.86
# Warehouse_SEA to Los Angeles using UPS: Reduced Cost = 0.00
# Warehouse_SEA to Los Angeles using USPS: Reduced Cost = 47.04
# Warehouse_SEA to Miami using Amazon Logistics: Reduced Cost = 20.32
# Warehouse_SEA to Miami using DHL: Reduced Cost = 0.95
# Warehouse_SEA to Miami using FedEx: Reduced Cost = 41.84
# Warehouse_SEA to Miami using LaserShip: Reduced Cost = 35.31
# Warehouse_SEA to Miami using OnTrac: Reduced Cost = 0.95
# Warehouse_SEA to Miami using UPS: Reduced Cost = 23.37
# Warehouse_SEA to Miami using USPS: Reduced Cost = 31.68
# Warehouse_SEA to Minneapolis using Amazon Logistics: Reduced Cost = 20.34
# Warehouse_SEA to Minneapolis using DHL: Reduced Cost = 56.81
# Warehouse_SEA to Minneapolis using FedEx: Reduced Cost = 31.09
# Warehouse_SEA to Minneapolis using LaserShip: Reduced Cost = 0.00
# Warehouse_SEA to Minneapolis using OnTrac: Reduced Cost = 22.01
# Warehouse_SEA to Minneapolis using UPS: Reduced Cost = 0.00
# Warehouse_SEA to Minneapolis using USPS: Reduced Cost = 37.37
# Warehouse_SEA to New York using Amazon Logistics: Reduced Cost = 21.94
# Warehouse_SEA to New York using DHL: Reduced Cost = 31.03
# Warehouse_SEA to New York using FedEx: Reduced Cost = 7.39
# Warehouse_SEA to New York using LaserShip: Reduced Cost = 1.00
# Warehouse_SEA to New York using OnTrac: Reduced Cost = 16.81
# Warehouse_SEA to New York using UPS: Reduced Cost = 0.00
# Warehouse_SEA to New York using USPS: Reduced Cost = 22.27
# Warehouse_SEA to Phoenix using Amazon Logistics: Reduced Cost = 7.83
# Warehouse_SEA to Phoenix using DHL: Reduced Cost = 48.36
# Warehouse_SEA to Phoenix using FedEx: Reduced Cost = 56.36
# Warehouse_SEA to Phoenix using LaserShip: Reduced Cost = 17.21
# Warehouse_SEA to Phoenix using OnTrac: Reduced Cost = 13.84
# Warehouse_SEA to Phoenix using UPS: Reduced Cost = 36.93
# Warehouse_SEA to Phoenix using USPS: Reduced Cost = 29.31
# Warehouse_SEA to Portland using Amazon Logistics: Reduced Cost = 28.21
# Warehouse_SEA to Portland using DHL: Reduced Cost = 18.17
# Warehouse_SEA to Portland using FedEx: Reduced Cost = 24.08
# Warehouse_SEA to Portland using LaserShip: Reduced Cost = 14.82
# Warehouse_SEA to Portland using OnTrac: Reduced Cost = 36.06
# Warehouse_SEA to Portland using UPS: Reduced Cost = 0.00
# Warehouse_SEA to Portland using USPS: Reduced Cost = 5.36
# Warehouse_SEA to San Francisco using Amazon Logistics: Reduced Cost = 23.51
# Warehouse_SEA to San Francisco using DHL: Reduced Cost = 46.26
# Warehouse_SEA to San Francisco using FedEx: Reduced Cost = 28.85
# Warehouse_SEA to San Francisco using LaserShip: Reduced Cost = 1.00
# Warehouse_SEA to San Francisco using OnTrac: Reduced Cost = 21.78
# Warehouse_SEA to San Francisco using UPS: Reduced Cost = 34.17
# Warehouse_SEA to San Francisco using USPS: Reduced Cost = 21.49
# Warehouse_SEA to Seattle using Amazon Logistics: Reduced Cost = 3.60
# Warehouse_SEA to Seattle using DHL: Reduced Cost = 47.33
# Warehouse_SEA to Seattle using FedEx: Reduced Cost = 33.30
# Warehouse_SEA to Seattle using LaserShip: Reduced Cost = 17.18
# Warehouse_SEA to Seattle using OnTrac: Reduced Cost = 34.28
# Warehouse_SEA to Seattle using UPS: Reduced Cost = 33.44
# Warehouse_SEA to Seattle using USPS: Reduced Cost = 12.08
# Warehouse_SF to Atlanta using Amazon Logistics: Reduced Cost = 11.72
# Warehouse_SF to Atlanta using DHL: Reduced Cost = 58.96
# Warehouse_SF to Atlanta using FedEx: Reduced Cost = 18.02
# Warehouse_SF to Atlanta using LaserShip: Reduced Cost = 14.84
# Warehouse_SF to Atlanta using OnTrac: Reduced Cost = 42.63
# Warehouse_SF to Atlanta using UPS: Reduced Cost = 13.27
# Warehouse_SF to Atlanta using USPS: Reduced Cost = 6.11
# Warehouse_SF to Boston using Amazon Logistics: Reduced Cost = 21.65
# Warehouse_SF to Boston using DHL: Reduced Cost = 42.48
# Warehouse_SF to Boston using FedEx: Reduced Cost = 10.81
# Warehouse_SF to Boston using LaserShip: Reduced Cost = 59.47
# Warehouse_SF to Boston using OnTrac: Reduced Cost = 13.09
# Warehouse_SF to Boston using UPS: Reduced Cost = 25.23
# Warehouse_SF to Boston using USPS: Reduced Cost = 23.08
# Warehouse_SF to Chicago using Amazon Logistics: Reduced Cost = 15.51
# Warehouse_SF to Chicago using DHL: Reduced Cost = 30.62
# Warehouse_SF to Chicago using FedEx: Reduced Cost = 1.53
# Warehouse_SF to Chicago using LaserShip: Reduced Cost = 7.89
# Warehouse_SF to Chicago using OnTrac: Reduced Cost = 45.84
# Warehouse_SF to Chicago using UPS: Reduced Cost = 1.53
# Warehouse_SF to Chicago using USPS: Reduced Cost = 1.53
# Warehouse_SF to Dallas using Amazon Logistics: Reduced Cost = 10.63
# Warehouse_SF to Dallas using DHL: Reduced Cost = 0.00
# Warehouse_SF to Dallas using FedEx: Reduced Cost = 25.61
# Warehouse_SF to Dallas using LaserShip: Reduced Cost = 25.11
# Warehouse_SF to Dallas using OnTrac: Reduced Cost = 29.95
# Warehouse_SF to Dallas using UPS: Reduced Cost = 20.12
# Warehouse_SF to Dallas using USPS: Reduced Cost = 16.78
# Warehouse_SF to Denver using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_SF to Denver using DHL: Reduced Cost = 31.96
# Warehouse_SF to Denver using FedEx: Reduced Cost = 13.38
# Warehouse_SF to Denver using LaserShip: Reduced Cost = 4.68
# Warehouse_SF to Denver using OnTrac: Reduced Cost = 14.66
# Warehouse_SF to Denver using UPS: Reduced Cost = 14.30
# Warehouse_SF to Denver using USPS: Reduced Cost = 29.53
# Warehouse_SF to Detroit using Amazon Logistics: Reduced Cost = 0.48
# Warehouse_SF to Detroit using DHL: Reduced Cost = 45.12
# Warehouse_SF to Detroit using FedEx: Reduced Cost = 4.54
# Warehouse_SF to Detroit using LaserShip: Reduced Cost = 15.23
# Warehouse_SF to Detroit using OnTrac: Reduced Cost = 29.82
# Warehouse_SF to Detroit using UPS: Reduced Cost = 40.23
# Warehouse_SF to Detroit using USPS: Reduced Cost = 17.99
# Warehouse_SF to Houston using Amazon Logistics: Reduced Cost = 34.47
# Warehouse_SF to Houston using DHL: Reduced Cost = 12.33
# Warehouse_SF to Houston using FedEx: Reduced Cost = 28.49
# Warehouse_SF to Houston using LaserShip: Reduced Cost = 7.73
# Warehouse_SF to Houston using OnTrac: Reduced Cost = 16.49
# Warehouse_SF to Houston using UPS: Reduced Cost = 21.82
# Warehouse_SF to Houston using USPS: Reduced Cost = 0.00
# Warehouse_SF to Los Angeles using Amazon Logistics: Reduced Cost = 20.36
# Warehouse_SF to Los Angeles using DHL: Reduced Cost = 15.93
# Warehouse_SF to Los Angeles using FedEx: Reduced Cost = 18.79
# Warehouse_SF to Los Angeles using LaserShip: Reduced Cost = 19.59
# Warehouse_SF to Los Angeles using OnTrac: Reduced Cost = 19.95
# Warehouse_SF to Los Angeles using UPS: Reduced Cost = 0.00
# Warehouse_SF to Los Angeles using USPS: Reduced Cost = 45.24
# Warehouse_SF to Miami using Amazon Logistics: Reduced Cost = 29.29
# Warehouse_SF to Miami using DHL: Reduced Cost = 4.67
# Warehouse_SF to Miami using FedEx: Reduced Cost = 26.23
# Warehouse_SF to Miami using LaserShip: Reduced Cost = 24.33
# Warehouse_SF to Miami using OnTrac: Reduced Cost = 42.71
# Warehouse_SF to Miami using UPS: Reduced Cost = 50.96
# Warehouse_SF to Miami using USPS: Reduced Cost = 10.12
# Warehouse_SF to Minneapolis using Amazon Logistics: Reduced Cost = 22.43
# Warehouse_SF to Minneapolis using DHL: Reduced Cost = 5.65
# Warehouse_SF to Minneapolis using FedEx: Reduced Cost = 22.44
# Warehouse_SF to Minneapolis using LaserShip: Reduced Cost = 19.97
# Warehouse_SF to Minneapolis using OnTrac: Reduced Cost = 9.85
# Warehouse_SF to Minneapolis using UPS: Reduced Cost = 0.00
# Warehouse_SF to Minneapolis using USPS: Reduced Cost = 22.88
# Warehouse_SF to New York using Amazon Logistics: Reduced Cost = 19.31
# Warehouse_SF to New York using DHL: Reduced Cost = 50.99
# Warehouse_SF to New York using FedEx: Reduced Cost = 26.24
# Warehouse_SF to New York using LaserShip: Reduced Cost = 10.06
# Warehouse_SF to New York using OnTrac: Reduced Cost = 55.89
# Warehouse_SF to New York using UPS: Reduced Cost = 9.56
# Warehouse_SF to New York using USPS: Reduced Cost = 4.26
# Warehouse_SF to Phoenix using Amazon Logistics: Reduced Cost = 18.32
# Warehouse_SF to Phoenix using DHL: Reduced Cost = 31.80
# Warehouse_SF to Phoenix using FedEx: Reduced Cost = 35.40
# Warehouse_SF to Phoenix using LaserShip: Reduced Cost = 27.83
# Warehouse_SF to Phoenix using OnTrac: Reduced Cost = 7.35
# Warehouse_SF to Phoenix using UPS: Reduced Cost = 9.58
# Warehouse_SF to Phoenix using USPS: Reduced Cost = 26.87
# Warehouse_SF to Portland using Amazon Logistics: Reduced Cost = 14.12
# Warehouse_SF to Portland using DHL: Reduced Cost = 22.15
# Warehouse_SF to Portland using FedEx: Reduced Cost = 11.46
# Warehouse_SF to Portland using LaserShip: Reduced Cost = 19.58
# Warehouse_SF to Portland using OnTrac: Reduced Cost = 22.13
# Warehouse_SF to Portland using UPS: Reduced Cost = 17.77
# Warehouse_SF to Portland using USPS: Reduced Cost = 18.36
# Warehouse_SF to San Francisco using Amazon Logistics: Reduced Cost = 8.94
# Warehouse_SF to San Francisco using DHL: Reduced Cost = 42.71
# Warehouse_SF to San Francisco using FedEx: Reduced Cost = 20.40
# Warehouse_SF to San Francisco using LaserShip: Reduced Cost = 4.64
# Warehouse_SF to San Francisco using OnTrac: Reduced Cost = 25.16
# Warehouse_SF to San Francisco using UPS: Reduced Cost = 0.00
# Warehouse_SF to San Francisco using USPS: Reduced Cost = 42.18
# Warehouse_SF to Seattle using Amazon Logistics: Reduced Cost = 10.07
# Warehouse_SF to Seattle using DHL: Reduced Cost = 57.46
# Warehouse_SF to Seattle using FedEx: Reduced Cost = 25.26
# Warehouse_SF to Seattle using LaserShip: Reduced Cost = 4.12
# Warehouse_SF to Seattle using OnTrac: Reduced Cost = 50.86
# Warehouse_SF to Seattle using UPS: Reduced Cost = 14.58
# Warehouse_SF to Seattle using USPS: Reduced Cost = 31.28
