# %%
# AI Disclaimer: As per the syllabus, our group used ChatGPT to assist with aggregating and cleaning the dataset using pandas
import pandas as pd
import gurobipy as gp
from gurobipy import GRB

# Load in the data
df = pd.read_csv("logistics_shipments_dataset.csv")

# Get rid of extra whitespace and clean the text
for column in ['Origin_Warehouse', 'Destination', 'Carrier']:
    df[column] = df[column].astype(str).str.replace(r"\s+", " ", regex = True).str.strip()

# Get all distinct names for origin warehouses, destination warehouses, and carriers
origins = sorted(df['Origin_Warehouse'].unique())
destinations = sorted(df['Destination'].unique())
carriers = sorted(df['Carrier'].unique())

# Map the key names to numeric index values in a dictionary
origin_index = {o: i for i, o in enumerate(origins)}
destination_index = {d: j for j, d in enumerate(destinations)}
carrier_index = {c: k for k, c in enumerate(carriers)}

# Reverse the mapping of the dictionary so index value is the key and name is the value
index_origin = {i: o for o, i in origin_index.items()}
index_destination = {j: d for d, j in destination_index.items()}
index_carrier = {k: c for c, k in carrier_index.items()}

# Length of each set for the origin, destination, and carrier
origins_len = len(origins)
dest_len = len(destinations)
carrier_len = len(carriers)

# Supply Capacity at each origin warehouse (S_i)
S = df.groupby('Origin_Warehouse')["Weight_kg"].sum().reindex(origins).fillna(0).tolist()

# Demand Capacity at each destination warehouse (D_j)
D = df.groupby('Destination')["Weight_kg"].sum().reindex(destinations).fillna(0).tolist()

# Making sure to balance supply and demand for a feasible and fair model
total_supply_kg = sum(S)
total_demand_kg = sum(D)

if total_demand_kg > 0:
    sd_ratio = total_supply_kg / total_demand_kg
    D = [d * sd_ratio for d in D]

# Carrier capacity for each carrier (C_k)
C = df.groupby("Carrier")["Weight_kg"].sum().reindex(carriers).fillna(0).tolist()

# Initialize a three-dimensional matrix for parameters c, t, p, g, and Y
co2_per_kg = [[[0 for k in carriers] for j in destinations] for i in origins]
transit_time = [[[0 for k in carriers] for j in destinations] for i in origins]
reliability = [[[0 for k in carriers] for j in destinations] for i in origins]
cost_per_kg = [[[0 for k in carriers] for j in destinations] for i in origins]
route_capacity = [[[0 for k in carriers] for j in destinations] for i in origins]

# CO2 factor per mile for different carriers (used in c_ijk calculation)
co2_factor = {'Amazon Logistics': 0.05, 'DHL': 0.15, 'FedEx': 0.08, 'LaserShip': 0.06, 'OnTrac': 0.12, 'UPS': 0.10, 'USPS': 0.11}

# Set minimum reliability rate for deliveries
R_min = 0.85

# Set the average transportation time in days for deliveries
T_average = 5

# Set the maximum C02 pollution allowed in kilograms of C02 (total supply * scaling constant)
P_max = total_supply_kg * 5

# Function to help clean missing values
def clean(x, def_value):
    if x is None:
        return def_value
    if pd.isna(x):
        return def_value
    return x

# Fill in parameters c, t, p, g, and Y for a route-carrier combination
for o in origins:
    for d in destinations:
        for c in carriers:

            # Set indexes for variables i, j, and k
            i = origin_index[o]
            j = destination_index[d]
            k = carrier_index[c]

            # Get the subset of data for that particular route-carrier combination 
            sub_df = df[(df['Origin_Warehouse'] == o) & (df['Destination'] == d) & (df['Carrier'] == c)]

            # If the subset is empty for a route-carrier combination, then fill c, t, p, g, and Y with constant average values
            if sub_df.empty:
                co2_per_kg[i][j][k] = 0.3
                transit_time[i][j][k] = 5
                reliability[i][j][k] = 0.775
                cost_per_kg[i][j][k] = 5
                route_capacity[i][j][k] = 25000
                continue


            # CO2/kilogram (c_ijk)
            avg_dist = clean(sub_df['Distance_miles'].mean(), 900)
            co2_per_kg[i][j][k] = avg_dist * co2_factor.get(c, 0.3)

            # Transit time (t_ijk)
            transit_time[i][j][k] = clean(sub_df['Transit_Days'].mean(), 5)

            # Reliability rate (p_ijk)
            delivered = sub_df[sub_df['Status'] == 'Delivered'].shape[0]
            total = sub_df.shape[0]
            if total > 0:
                reliability[i][j][k] = delivered / total
            else:
                reliability[i][j][k] = 0.775

            # Cost/kilogram (g_ijk)
            avg_cost = clean(sub_df['Cost'].mean(), 5)
            avg_weight = clean(sub_df['Weight_kg'].mean(), 1)
            cost_per_kg[i][j][k] = avg_cost / avg_weight

            # Route capacity (Y_ijk)
            avg_weight = clean(sub_df['Weight_kg'].mean(), 0)
            route_capacity[i][j][k] = max(avg_weight, 25000)

# Initialize model
m = gp.Model("Shipping")
m.Params.LogToConsole = 0

# Decision variable (x_ijk) for kilograms to be shipped on a route using a specific carrier
x = m.addVars(origins_len, dest_len, carrier_len, lb = 0, name = "x")

# Objective Function
m.setObjective(gp.quicksum(cost_per_kg[i][j][k] * x[i,j,k] for i in range(origins_len) for j in range(dest_len) for k in range(carrier_len)), GRB.MINIMIZE)

# Supply Constraint
for i in range(origins_len):
    m.addConstr(gp.quicksum(x[i,j,k] for j in range(dest_len) for k in range(carrier_len)) <= S[i])

# Demand Constraint
for j in range(dest_len):
    m.addConstr(gp.quicksum(x[i,j,k] for i in range(origins_len) for k in range(carrier_len)) == D[j])

# Carrier Capacity Constraint
for k in range(carrier_len):
    m.addConstr(gp.quicksum(x[i,j,k] for i in range(origins_len) for j in range(dest_len)) <= C[k])

# C02 Constraint
m.addConstr(gp.quicksum(co2_per_kg[i][j][k] * x[i,j,k] for i in range(origins_len) for j in range(dest_len) for k in range(carrier_len)) <= P_max)

# Transit Time Constraint
total_kg = gp.quicksum(x[i,j,k] for i in range(origins_len) for j in range(dest_len) for k in range(carrier_len))

m.addConstr(gp.quicksum(transit_time[i][j][k] * x[i,j,k] for i in range(origins_len) for j in range(dest_len) for k in range(carrier_len)) <= T_average * total_kg)

# Reliability Constraint
m.addConstr(gp.quicksum(reliability[i][j][k] * x[i,j,k] for i in range(origins_len) for j in range(dest_len) for k in range(carrier_len)) >= R_min * total_kg)

# Route Capacity Constraint
for i in range(origins_len):
    for j in range(dest_len):
        for k in range(carrier_len):
            m.addConstr(x[i,j,k] <= route_capacity[i][j][k])

# Optimize model
m.optimize()

# Print results for optimal shipping routes and weights shipped for chosen routes
print("\nOptimal Shipping Cost:", m.objVal)
print("\nShipment Plan:")
for i in range(origins_len):
    for j in range(dest_len):
        for k in range(carrier_len):
            cost = x[i,j,k].x
            if cost > 0:
                print(f"{index_origin[i]} to {index_destination[j]} using {index_carrier[k]}: {cost:.2f} kg")

# Print the reduced costs
print("\nReduced Costs:")
for i in range(origins_len):
    for j in range(dest_len):
        for k in range(carrier_len):
            rc = x[i,j,k].RC
            print(f"{index_origin[i]} to {index_destination[j]} using {index_carrier[k]}: Reduced Cost = {rc:.4f}")
# Out:
# Set parameter LogToConsole to value 0
#
# Optimal Shipping Cost: 216003.9765173699
#
# Shipment Plan:
# Warehouse_ATL to Denver using OnTrac: 1177.88 kg
# Warehouse_ATL to Houston using Amazon Logistics: 1508.37 kg
# Warehouse_ATL to Portland using DHL: 616.95 kg
# Warehouse_ATL to Seattle using USPS: 3046.90 kg
# Warehouse_BOS to Boston using UPS: 2272.23 kg
# Warehouse_BOS to New York using USPS: 2876.31 kg
# Warehouse_BOS to Phoenix using FedEx: 4767.70 kg
# Warehouse_BOS to Portland using FedEx: 46.36 kg
# Warehouse_CHI to Chicago using LaserShip: 4343.00 kg
# Warehouse_CHI to Detroit using DHL: 1256.21 kg
# Warehouse_CHI to New York using UPS: 79.09 kg
# Warehouse_DEN to Miami using LaserShip: 3161.40 kg
# Warehouse_DEN to Portland using Amazon Logistics: 1922.80 kg
# Warehouse_HOU to Denver using USPS: 794.30 kg
# Warehouse_HOU to Los Angeles using FedEx: 3379.49 kg
# Warehouse_HOU to Portland using OnTrac: 1391.89 kg
# Warehouse_HOU to San Francisco using DHL: 148.62 kg
# Warehouse_LA to Atlanta using OnTrac: 3222.54 kg
# Warehouse_LA to Boston using FedEx: 1978.57 kg
# Warehouse_LA to Detroit using OnTrac: 2151.89 kg
# Warehouse_MIA to Denver using DHL: 1627.92 kg
# Warehouse_MIA to San Francisco using FedEx: 3478.88 kg
# Warehouse_NYC to Boston using Amazon Logistics: 3758.23 kg
# Warehouse_NYC to Boston using UPS: 892.17 kg
# Warehouse_SEA to Atlanta using USPS: 357.06 kg
# Warehouse_SEA to Los Angeles using UPS: 18.74 kg
# Warehouse_SEA to Minneapolis using LaserShip: 1280.70 kg
# Warehouse_SEA to Minneapolis using UPS: 3068.20 kg
# Warehouse_SF to Dallas using DHL: 3380.70 kg
# Warehouse_SF to Houston using USPS: 2117.03 kg
# Warehouse_SF to Los Angeles using UPS: 247.47 kg
#
# Reduced Costs:
# Warehouse_ATL to Atlanta using Amazon Logistics: Reduced Cost = 16.8245
# Warehouse_ATL to Atlanta using DHL: Reduced Cost = 0.0000
# Warehouse_ATL to Atlanta using FedEx: Reduced Cost = 30.3849
# Warehouse_ATL to Atlanta using LaserShip: Reduced Cost = 1.0044
# Warehouse_ATL to Atlanta using OnTrac: Reduced Cost = 35.3042
# Warehouse_ATL to Atlanta using UPS: Reduced Cost = 34.7513
# Warehouse_ATL to Atlanta using USPS: Reduced Cost = 6.3504
# Warehouse_ATL to Boston using Amazon Logistics: Reduced Cost = 21.3209
# Warehouse_ATL to Boston using DHL: Reduced Cost = 46.5988
# Warehouse_ATL to Boston using FedEx: Reduced Cost = 21.0973
# Warehouse_ATL to Boston using LaserShip: Reduced Cost = 8.2882
# Warehouse_ATL to Boston using OnTrac: Reduced Cost = 52.4521
# Warehouse_ATL to Boston using UPS: Reduced Cost = 25.7861
# Warehouse_ATL to Boston using USPS: Reduced Cost = 34.1508
# Warehouse_ATL to Chicago using Amazon Logistics: Reduced Cost = 18.4579
# Warehouse_ATL to Chicago using DHL: Reduced Cost = 35.6267
# Warehouse_ATL to Chicago using FedEx: Reduced Cost = 0.2934
# Warehouse_ATL to Chicago using LaserShip: Reduced Cost = 19.6180
# Warehouse_ATL to Chicago using OnTrac: Reduced Cost = 1.5252
# Warehouse_ATL to Chicago using UPS: Reduced Cost = 3.9649
# Warehouse_ATL to Chicago using USPS: Reduced Cost = 10.5650
# Warehouse_ATL to Dallas using Amazon Logistics: Reduced Cost = 14.7135
# Warehouse_ATL to Dallas using DHL: Reduced Cost = 69.7143
# Warehouse_ATL to Dallas using FedEx: Reduced Cost = 31.0007
# Warehouse_ATL to Dallas using LaserShip: Reduced Cost = 16.9720
# Warehouse_ATL to Dallas using OnTrac: Reduced Cost = 22.1567
# Warehouse_ATL to Dallas using UPS: Reduced Cost = 12.4948
# Warehouse_ATL to Dallas using USPS: Reduced Cost = 42.3473
# Warehouse_ATL to Denver using Amazon Logistics: Reduced Cost = 21.4777
# Warehouse_ATL to Denver using DHL: Reduced Cost = 36.4677
# Warehouse_ATL to Denver using FedEx: Reduced Cost = 22.2437
# Warehouse_ATL to Denver using LaserShip: Reduced Cost = 5.8356
# Warehouse_ATL to Denver using OnTrac: Reduced Cost = 0.0000
# Warehouse_ATL to Denver using UPS: Reduced Cost = 3.0333
# Warehouse_ATL to Denver using USPS: Reduced Cost = 0.0000
# Warehouse_ATL to Detroit using Amazon Logistics: Reduced Cost = 13.3136
# Warehouse_ATL to Detroit using DHL: Reduced Cost = 25.7217
# Warehouse_ATL to Detroit using FedEx: Reduced Cost = 21.7048
# Warehouse_ATL to Detroit using LaserShip: Reduced Cost = 18.3257
# Warehouse_ATL to Detroit using OnTrac: Reduced Cost = 13.9178
# Warehouse_ATL to Detroit using UPS: Reduced Cost = 0.0000
# Warehouse_ATL to Detroit using USPS: Reduced Cost = 36.3913
# Warehouse_ATL to Houston using Amazon Logistics: Reduced Cost = 0.0000
# Warehouse_ATL to Houston using DHL: Reduced Cost = 51.3939
# Warehouse_ATL to Houston using FedEx: Reduced Cost = 16.7861
# Warehouse_ATL to Houston using LaserShip: Reduced Cost = 8.0107
# Warehouse_ATL to Houston using OnTrac: Reduced Cost = 38.3755
# Warehouse_ATL to Houston using UPS: Reduced Cost = 32.1712
# Warehouse_ATL to Houston using USPS: Reduced Cost = 7.7931
# Warehouse_ATL to Los Angeles using Amazon Logistics: Reduced Cost = 12.0910
# Warehouse_ATL to Los Angeles using DHL: Reduced Cost = 0.0000
# Warehouse_ATL to Los Angeles using FedEx: Reduced Cost = 16.7591
# Warehouse_ATL to Los Angeles using LaserShip: Reduced Cost = 1.0044
# Warehouse_ATL to Los Angeles using OnTrac: Reduced Cost = 9.4376
# Warehouse_ATL to Los Angeles using UPS: Reduced Cost = 0.0000
# Warehouse_ATL to Los Angeles using USPS: Reduced Cost = 19.9575
# Warehouse_ATL to Miami using Amazon Logistics: Reduced Cost = 9.5450
# Warehouse_ATL to Miami using DHL: Reduced Cost = 54.3782
# Warehouse_ATL to Miami using FedEx: Reduced Cost = 15.5395
# Warehouse_ATL to Miami using LaserShip: Reduced Cost = 26.4928
# Warehouse_ATL to Miami using OnTrac: Reduced Cost = 24.2953
# Warehouse_ATL to Miami using UPS: Reduced Cost = 12.3313
# Warehouse_ATL to Miami using USPS: Reduced Cost = 24.7943
# Warehouse_ATL to Minneapolis using Amazon Logistics: Reduced Cost = 11.3016
# Warehouse_ATL to Minneapolis using DHL: Reduced Cost = 26.7804
# Warehouse_ATL to Minneapolis using FedEx: Reduced Cost = 4.7581
# Warehouse_ATL to Minneapolis using LaserShip: Reduced Cost = 13.6553
# Warehouse_ATL to Minneapolis using OnTrac: Reduced Cost = 21.6827
# Warehouse_ATL to Minneapolis using UPS: Reduced Cost = 40.3740
# Warehouse_ATL to Minneapolis using USPS: Reduced Cost = 21.9617
# Warehouse_ATL to New York using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_ATL to New York using DHL: Reduced Cost = 55.4729
# Warehouse_ATL to New York using FedEx: Reduced Cost = 22.2690
# Warehouse_ATL to New York using LaserShip: Reduced Cost = 4.5263
# Warehouse_ATL to New York using OnTrac: Reduced Cost = 12.3210
# Warehouse_ATL to New York using UPS: Reduced Cost = 20.1958
# Warehouse_ATL to New York using USPS: Reduced Cost = 0.0000
# Warehouse_ATL to Phoenix using Amazon Logistics: Reduced Cost = 0.8573
# Warehouse_ATL to Phoenix using DHL: Reduced Cost = 92.2445
# Warehouse_ATL to Phoenix using FedEx: Reduced Cost = 17.4463
# Warehouse_ATL to Phoenix using LaserShip: Reduced Cost = 16.8987
# Warehouse_ATL to Phoenix using OnTrac: Reduced Cost = 24.6092
# Warehouse_ATL to Phoenix using UPS: Reduced Cost = 26.9698
# Warehouse_ATL to Phoenix using USPS: Reduced Cost = 21.0354
# Warehouse_ATL to Portland using Amazon Logistics: Reduced Cost = 25.2919
# Warehouse_ATL to Portland using DHL: Reduced Cost = 0.0000
# Warehouse_ATL to Portland using FedEx: Reduced Cost = 16.0559
# Warehouse_ATL to Portland using LaserShip: Reduced Cost = 40.0387
# Warehouse_ATL to Portland using OnTrac: Reduced Cost = 0.0642
# Warehouse_ATL to Portland using UPS: Reduced Cost = 3.4055
# Warehouse_ATL to Portland using USPS: Reduced Cost = 25.5057
# Warehouse_ATL to San Francisco using Amazon Logistics: Reduced Cost = 0.2384
# Warehouse_ATL to San Francisco using DHL: Reduced Cost = 57.2976
# Warehouse_ATL to San Francisco using FedEx: Reduced Cost = 11.1302
# Warehouse_ATL to San Francisco using LaserShip: Reduced Cost = 21.1231
# Warehouse_ATL to San Francisco using OnTrac: Reduced Cost = 12.6444
# Warehouse_ATL to San Francisco using UPS: Reduced Cost = 28.8694
# Warehouse_ATL to San Francisco using USPS: Reduced Cost = 23.6266
# Warehouse_ATL to Seattle using Amazon Logistics: Reduced Cost = 14.9983
# Warehouse_ATL to Seattle using DHL: Reduced Cost = 33.0348
# Warehouse_ATL to Seattle using FedEx: Reduced Cost = 13.4508
# Warehouse_ATL to Seattle using LaserShip: Reduced Cost = 11.7990
# Warehouse_ATL to Seattle using OnTrac: Reduced Cost = 3.1202
# Warehouse_ATL to Seattle using UPS: Reduced Cost = 106.2661
# Warehouse_ATL to Seattle using USPS: Reduced Cost = 0.0000
# Warehouse_BOS to Atlanta using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_BOS to Atlanta using DHL: Reduced Cost = 25.4122
# Warehouse_BOS to Atlanta using FedEx: Reduced Cost = 0.0000
# Warehouse_BOS to Atlanta using LaserShip: Reduced Cost = 14.8938
# Warehouse_BOS to Atlanta using OnTrac: Reduced Cost = 38.1451
# Warehouse_BOS to Atlanta using UPS: Reduced Cost = 16.3582
# Warehouse_BOS to Atlanta using USPS: Reduced Cost = 10.2066
# Warehouse_BOS to Boston using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_BOS to Boston using DHL: Reduced Cost = 62.7128
# Warehouse_BOS to Boston using FedEx: Reduced Cost = 12.5658
# Warehouse_BOS to Boston using LaserShip: Reduced Cost = 4.9761
# Warehouse_BOS to Boston using OnTrac: Reduced Cost = 50.7846
# Warehouse_BOS to Boston using UPS: Reduced Cost = 0.0000
# Warehouse_BOS to Boston using USPS: Reduced Cost = 29.3671
# Warehouse_BOS to Chicago using Amazon Logistics: Reduced Cost = 15.8293
# Warehouse_BOS to Chicago using DHL: Reduced Cost = 31.5337
# Warehouse_BOS to Chicago using FedEx: Reduced Cost = 28.5773
# Warehouse_BOS to Chicago using LaserShip: Reduced Cost = 20.3368
# Warehouse_BOS to Chicago using OnTrac: Reduced Cost = 13.7116
# Warehouse_BOS to Chicago using UPS: Reduced Cost = 18.0581
# Warehouse_BOS to Chicago using USPS: Reduced Cost = 37.1917
# Warehouse_BOS to Dallas using Amazon Logistics: Reduced Cost = 3.4351
# Warehouse_BOS to Dallas using DHL: Reduced Cost = 46.9209
# Warehouse_BOS to Dallas using FedEx: Reduced Cost = 22.6890
# Warehouse_BOS to Dallas using LaserShip: Reduced Cost = 22.1382
# Warehouse_BOS to Dallas using OnTrac: Reduced Cost = 9.5561
# Warehouse_BOS to Dallas using UPS: Reduced Cost = 41.0308
# Warehouse_BOS to Dallas using USPS: Reduced Cost = 0.0000
# Warehouse_BOS to Denver using Amazon Logistics: Reduced Cost = 24.7654
# Warehouse_BOS to Denver using DHL: Reduced Cost = 32.1939
# Warehouse_BOS to Denver using FedEx: Reduced Cost = 1.6225
# Warehouse_BOS to Denver using LaserShip: Reduced Cost = 27.1767
# Warehouse_BOS to Denver using OnTrac: Reduced Cost = 43.5385
# Warehouse_BOS to Denver using UPS: Reduced Cost = 43.8486
# Warehouse_BOS to Denver using USPS: Reduced Cost = 6.1142
# Warehouse_BOS to Detroit using Amazon Logistics: Reduced Cost = 21.9900
# Warehouse_BOS to Detroit using DHL: Reduced Cost = 34.6639
# Warehouse_BOS to Detroit using FedEx: Reduced Cost = 0.0000
# Warehouse_BOS to Detroit using LaserShip: Reduced Cost = 0.8174
# Warehouse_BOS to Detroit using OnTrac: Reduced Cost = 47.0338
# Warehouse_BOS to Detroit using UPS: Reduced Cost = 37.2930
# Warehouse_BOS to Detroit using USPS: Reduced Cost = 23.3461
# Warehouse_BOS to Houston using Amazon Logistics: Reduced Cost = 2.6775
# Warehouse_BOS to Houston using DHL: Reduced Cost = 34.4345
# Warehouse_BOS to Houston using FedEx: Reduced Cost = 38.2089
# Warehouse_BOS to Houston using LaserShip: Reduced Cost = 1.2083
# Warehouse_BOS to Houston using OnTrac: Reduced Cost = 0.0000
# Warehouse_BOS to Houston using UPS: Reduced Cost = 582.5482
# Warehouse_BOS to Houston using USPS: Reduced Cost = 22.1646
# Warehouse_BOS to Los Angeles using Amazon Logistics: Reduced Cost = 1.8310
# Warehouse_BOS to Los Angeles using DHL: Reduced Cost = 5.5307
# Warehouse_BOS to Los Angeles using FedEx: Reduced Cost = 0.0000
# Warehouse_BOS to Los Angeles using LaserShip: Reduced Cost = 2.7771
# Warehouse_BOS to Los Angeles using OnTrac: Reduced Cost = 35.7354
# Warehouse_BOS to Los Angeles using UPS: Reduced Cost = 31.1774
# Warehouse_BOS to Los Angeles using USPS: Reduced Cost = 56.7240
# Warehouse_BOS to Miami using Amazon Logistics: Reduced Cost = 12.1776
# Warehouse_BOS to Miami using DHL: Reduced Cost = 27.4507
# Warehouse_BOS to Miami using FedEx: Reduced Cost = 24.3561
# Warehouse_BOS to Miami using LaserShip: Reduced Cost = 28.8339
# Warehouse_BOS to Miami using OnTrac: Reduced Cost = 44.4446
# Warehouse_BOS to Miami using UPS: Reduced Cost = 35.8715
# Warehouse_BOS to Miami using USPS: Reduced Cost = 25.8947
# Warehouse_BOS to Minneapolis using Amazon Logistics: Reduced Cost = 15.5998
# Warehouse_BOS to Minneapolis using DHL: Reduced Cost = 39.3410
# Warehouse_BOS to Minneapolis using FedEx: Reduced Cost = 0.0000
# Warehouse_BOS to Minneapolis using LaserShip: Reduced Cost = 11.0484
# Warehouse_BOS to Minneapolis using OnTrac: Reduced Cost = 34.0105
# Warehouse_BOS to Minneapolis using UPS: Reduced Cost = 21.1272
# Warehouse_BOS to Minneapolis using USPS: Reduced Cost = 13.7828
# Warehouse_BOS to New York using Amazon Logistics: Reduced Cost = 59.4961
# Warehouse_BOS to New York using DHL: Reduced Cost = 27.7917
# Warehouse_BOS to New York using FedEx: Reduced Cost = 64.5902
# Warehouse_BOS to New York using LaserShip: Reduced Cost = 13.9299
# Warehouse_BOS to New York using OnTrac: Reduced Cost = 42.3315
# Warehouse_BOS to New York using UPS: Reduced Cost = 3.4912
# Warehouse_BOS to New York using USPS: Reduced Cost = 0.0000
# Warehouse_BOS to Phoenix using Amazon Logistics: Reduced Cost = 10.3160
# Warehouse_BOS to Phoenix using DHL: Reduced Cost = 38.6380
# Warehouse_BOS to Phoenix using FedEx: Reduced Cost = 0.0000
# Warehouse_BOS to Phoenix using LaserShip: Reduced Cost = 9.1418
# Warehouse_BOS to Phoenix using OnTrac: Reduced Cost = 45.4569
# Warehouse_BOS to Phoenix using UPS: Reduced Cost = 52.8054
# Warehouse_BOS to Phoenix using USPS: Reduced Cost = 9.6459
# Warehouse_BOS to Portland using Amazon Logistics: Reduced Cost = 15.2652
# Warehouse_BOS to Portland using DHL: Reduced Cost = 88.3297
# Warehouse_BOS to Portland using FedEx: Reduced Cost = 0.0000
# Warehouse_BOS to Portland using LaserShip: Reduced Cost = 25.0041
# Warehouse_BOS to Portland using OnTrac: Reduced Cost = 37.0267
# Warehouse_BOS to Portland using UPS: Reduced Cost = 42.5739
# Warehouse_BOS to Portland using USPS: Reduced Cost = 39.5685
# Warehouse_BOS to San Francisco using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_BOS to San Francisco using DHL: Reduced Cost = 0.0000
# Warehouse_BOS to San Francisco using FedEx: Reduced Cost = 33.8226
# Warehouse_BOS to San Francisco using LaserShip: Reduced Cost = 30.7413
# Warehouse_BOS to San Francisco using OnTrac: Reduced Cost = 6.6445
# Warehouse_BOS to San Francisco using UPS: Reduced Cost = 0.0000
# Warehouse_BOS to San Francisco using USPS: Reduced Cost = 66.8283
# Warehouse_BOS to Seattle using Amazon Logistics: Reduced Cost = 3.5954
# Warehouse_BOS to Seattle using DHL: Reduced Cost = 55.8396
# Warehouse_BOS to Seattle using FedEx: Reduced Cost = 26.4493
# Warehouse_BOS to Seattle using LaserShip: Reduced Cost = 4.1246
# Warehouse_BOS to Seattle using OnTrac: Reduced Cost = 39.3162
# Warehouse_BOS to Seattle using UPS: Reduced Cost = 14.4220
# Warehouse_BOS to Seattle using USPS: Reduced Cost = 29.3409
# Warehouse_CHI to Atlanta using Amazon Logistics: Reduced Cost = 15.6678
# Warehouse_CHI to Atlanta using DHL: Reduced Cost = 38.4324
# Warehouse_CHI to Atlanta using FedEx: Reduced Cost = 24.6278
# Warehouse_CHI to Atlanta using LaserShip: Reduced Cost = 23.7067
# Warehouse_CHI to Atlanta using OnTrac: Reduced Cost = 32.8346
# Warehouse_CHI to Atlanta using UPS: Reduced Cost = 27.7465
# Warehouse_CHI to Atlanta using USPS: Reduced Cost = 43.3969
# Warehouse_CHI to Boston using Amazon Logistics: Reduced Cost = 5.8025
# Warehouse_CHI to Boston using DHL: Reduced Cost = 86.2414
# Warehouse_CHI to Boston using FedEx: Reduced Cost = 25.0010
# Warehouse_CHI to Boston using LaserShip: Reduced Cost = 15.0440
# Warehouse_CHI to Boston using OnTrac: Reduced Cost = 64.6400
# Warehouse_CHI to Boston using UPS: Reduced Cost = 27.2100
# Warehouse_CHI to Boston using USPS: Reduced Cost = 0.0000
# Warehouse_CHI to Chicago using Amazon Logistics: Reduced Cost = 40.2110
# Warehouse_CHI to Chicago using DHL: Reduced Cost = 20.5480
# Warehouse_CHI to Chicago using FedEx: Reduced Cost = 6.6867
# Warehouse_CHI to Chicago using LaserShip: Reduced Cost = 0.0000
# Warehouse_CHI to Chicago using OnTrac: Reduced Cost = 18.9803
# Warehouse_CHI to Chicago using UPS: Reduced Cost = 9.8163
# Warehouse_CHI to Chicago using USPS: Reduced Cost = 35.6938
# Warehouse_CHI to Dallas using Amazon Logistics: Reduced Cost = 19.6441
# Warehouse_CHI to Dallas using DHL: Reduced Cost = 0.0000
# Warehouse_CHI to Dallas using FedEx: Reduced Cost = 37.0702
# Warehouse_CHI to Dallas using LaserShip: Reduced Cost = 1.0044
# Warehouse_CHI to Dallas using OnTrac: Reduced Cost = 11.8395
# Warehouse_CHI to Dallas using UPS: Reduced Cost = 30.2803
# Warehouse_CHI to Dallas using USPS: Reduced Cost = 24.7317
# Warehouse_CHI to Denver using Amazon Logistics: Reduced Cost = 9.4680
# Warehouse_CHI to Denver using DHL: Reduced Cost = 26.5882
# Warehouse_CHI to Denver using FedEx: Reduced Cost = 14.1560
# Warehouse_CHI to Denver using LaserShip: Reduced Cost = 10.1048
# Warehouse_CHI to Denver using OnTrac: Reduced Cost = 19.7458
# Warehouse_CHI to Denver using UPS: Reduced Cost = 18.5459
# Warehouse_CHI to Denver using USPS: Reduced Cost = 20.2256
# Warehouse_CHI to Detroit using Amazon Logistics: Reduced Cost = 0.4005
# Warehouse_CHI to Detroit using DHL: Reduced Cost = 0.0000
# Warehouse_CHI to Detroit using FedEx: Reduced Cost = 0.8708
# Warehouse_CHI to Detroit using LaserShip: Reduced Cost = 0.6305
# Warehouse_CHI to Detroit using OnTrac: Reduced Cost = 2.6719
# Warehouse_CHI to Detroit using UPS: Reduced Cost = 2.9156
# Warehouse_CHI to Detroit using USPS: Reduced Cost = 3.4227
# Warehouse_CHI to Houston using Amazon Logistics: Reduced Cost = 26.5438
# Warehouse_CHI to Houston using DHL: Reduced Cost = 53.6719
# Warehouse_CHI to Houston using FedEx: Reduced Cost = 14.0828
# Warehouse_CHI to Houston using LaserShip: Reduced Cost = 28.1336
# Warehouse_CHI to Houston using OnTrac: Reduced Cost = 57.1304
# Warehouse_CHI to Houston using UPS: Reduced Cost = 29.1598
# Warehouse_CHI to Houston using USPS: Reduced Cost = 42.9416
# Warehouse_CHI to Los Angeles using Amazon Logistics: Reduced Cost = 7.9538
# Warehouse_CHI to Los Angeles using DHL: Reduced Cost = 3.2389
# Warehouse_CHI to Los Angeles using FedEx: Reduced Cost = 0.2464
# Warehouse_CHI to Los Angeles using LaserShip: Reduced Cost = 1.0044
# Warehouse_CHI to Los Angeles using OnTrac: Reduced Cost = 6.6038
# Warehouse_CHI to Los Angeles using UPS: Reduced Cost = 30.1550
# Warehouse_CHI to Los Angeles using USPS: Reduced Cost = 12.3311
# Warehouse_CHI to Miami using Amazon Logistics: Reduced Cost = 13.1917
# Warehouse_CHI to Miami using DHL: Reduced Cost = 0.9491
# Warehouse_CHI to Miami using FedEx: Reduced Cost = 17.0824
# Warehouse_CHI to Miami using LaserShip: Reduced Cost = 18.1580
# Warehouse_CHI to Miami using OnTrac: Reduced Cost = 27.1739
# Warehouse_CHI to Miami using UPS: Reduced Cost = 0.9491
# Warehouse_CHI to Miami using USPS: Reduced Cost = 35.1245
# Warehouse_CHI to Minneapolis using Amazon Logistics: Reduced Cost = 12.9946
# Warehouse_CHI to Minneapolis using DHL: Reduced Cost = 31.1746
# Warehouse_CHI to Minneapolis using FedEx: Reduced Cost = 14.5251
# Warehouse_CHI to Minneapolis using LaserShip: Reduced Cost = 10.7979
# Warehouse_CHI to Minneapolis using OnTrac: Reduced Cost = 2.8999
# Warehouse_CHI to Minneapolis using UPS: Reduced Cost = 0.0000
# Warehouse_CHI to Minneapolis using USPS: Reduced Cost = 31.2299
# Warehouse_CHI to New York using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_CHI to New York using DHL: Reduced Cost = 13.1952
# Warehouse_CHI to New York using FedEx: Reduced Cost = 33.1896
# Warehouse_CHI to New York using LaserShip: Reduced Cost = 1.0044
# Warehouse_CHI to New York using OnTrac: Reduced Cost = 50.7071
# Warehouse_CHI to New York using UPS: Reduced Cost = 0.0000
# Warehouse_CHI to New York using USPS: Reduced Cost = 10.3569
# Warehouse_CHI to Phoenix using Amazon Logistics: Reduced Cost = 0.8573
# Warehouse_CHI to Phoenix using DHL: Reduced Cost = 46.2436
# Warehouse_CHI to Phoenix using FedEx: Reduced Cost = 0.3821
# Warehouse_CHI to Phoenix using LaserShip: Reduced Cost = 22.2419
# Warehouse_CHI to Phoenix using OnTrac: Reduced Cost = 30.8845
# Warehouse_CHI to Phoenix using UPS: Reduced Cost = 0.3821
# Warehouse_CHI to Phoenix using USPS: Reduced Cost = 0.3821
# Warehouse_CHI to Portland using Amazon Logistics: Reduced Cost = 11.5909
# Warehouse_CHI to Portland using DHL: Reduced Cost = 4.9838
# Warehouse_CHI to Portland using FedEx: Reduced Cost = 3.5602
# Warehouse_CHI to Portland using LaserShip: Reduced Cost = 14.1371
# Warehouse_CHI to Portland using OnTrac: Reduced Cost = 0.3042
# Warehouse_CHI to Portland using UPS: Reduced Cost = 57.6639
# Warehouse_CHI to Portland using USPS: Reduced Cost = 31.3507
# Warehouse_CHI to San Francisco using Amazon Logistics: Reduced Cost = 10.5977
# Warehouse_CHI to San Francisco using DHL: Reduced Cost = 51.2345
# Warehouse_CHI to San Francisco using FedEx: Reduced Cost = 25.7662
# Warehouse_CHI to San Francisco using LaserShip: Reduced Cost = 9.6959
# Warehouse_CHI to San Francisco using OnTrac: Reduced Cost = 13.1809
# Warehouse_CHI to San Francisco using UPS: Reduced Cost = 0.0000
# Warehouse_CHI to San Francisco using USPS: Reduced Cost = 3.5223
# Warehouse_CHI to Seattle using Amazon Logistics: Reduced Cost = 35.0849
# Warehouse_CHI to Seattle using DHL: Reduced Cost = 68.1793
# Warehouse_CHI to Seattle using FedEx: Reduced Cost = 46.3491
# Warehouse_CHI to Seattle using LaserShip: Reduced Cost = 8.5749
# Warehouse_CHI to Seattle using OnTrac: Reduced Cost = 42.8376
# Warehouse_CHI to Seattle using UPS: Reduced Cost = 43.4619
# Warehouse_CHI to Seattle using USPS: Reduced Cost = 38.1105
# Warehouse_DEN to Atlanta using Amazon Logistics: Reduced Cost = 15.3006
# Warehouse_DEN to Atlanta using DHL: Reduced Cost = 70.0398
# Warehouse_DEN to Atlanta using FedEx: Reduced Cost = 9.2136
# Warehouse_DEN to Atlanta using LaserShip: Reduced Cost = 12.9794
# Warehouse_DEN to Atlanta using OnTrac: Reduced Cost = 17.9830
# Warehouse_DEN to Atlanta using UPS: Reduced Cost = 40.5724
# Warehouse_DEN to Atlanta using USPS: Reduced Cost = 16.1987
# Warehouse_DEN to Boston using Amazon Logistics: Reduced Cost = 19.4346
# Warehouse_DEN to Boston using DHL: Reduced Cost = 48.9577
# Warehouse_DEN to Boston using FedEx: Reduced Cost = 35.5814
# Warehouse_DEN to Boston using LaserShip: Reduced Cost = 12.1247
# Warehouse_DEN to Boston using OnTrac: Reduced Cost = 33.5065
# Warehouse_DEN to Boston using UPS: Reduced Cost = 0.2222
# Warehouse_DEN to Boston using USPS: Reduced Cost = 45.7912
# Warehouse_DEN to Chicago using Amazon Logistics: Reduced Cost = 27.7421
# Warehouse_DEN to Chicago using DHL: Reduced Cost = 53.5750
# Warehouse_DEN to Chicago using FedEx: Reduced Cost = 26.1578
# Warehouse_DEN to Chicago using LaserShip: Reduced Cost = 13.4263
# Warehouse_DEN to Chicago using OnTrac: Reduced Cost = 43.9050
# Warehouse_DEN to Chicago using UPS: Reduced Cost = 30.0103
# Warehouse_DEN to Chicago using USPS: Reduced Cost = 38.5870
# Warehouse_DEN to Dallas using Amazon Logistics: Reduced Cost = 31.2722
# Warehouse_DEN to Dallas using DHL: Reduced Cost = 25.2731
# Warehouse_DEN to Dallas using FedEx: Reduced Cost = 16.4139
# Warehouse_DEN to Dallas using LaserShip: Reduced Cost = 2.8091
# Warehouse_DEN to Dallas using OnTrac: Reduced Cost = 42.7725
# Warehouse_DEN to Dallas using UPS: Reduced Cost = 30.8924
# Warehouse_DEN to Dallas using USPS: Reduced Cost = 10.9294
# Warehouse_DEN to Denver using Amazon Logistics: Reduced Cost = 2.2185
# Warehouse_DEN to Denver using DHL: Reduced Cost = 29.2764
# Warehouse_DEN to Denver using FedEx: Reduced Cost = 10.6453
# Warehouse_DEN to Denver using LaserShip: Reduced Cost = 1.2265
# Warehouse_DEN to Denver using OnTrac: Reduced Cost = 25.2855
# Warehouse_DEN to Denver using UPS: Reduced Cost = 37.3967
# Warehouse_DEN to Denver using USPS: Reduced Cost = 0.2222
# Warehouse_DEN to Detroit using Amazon Logistics: Reduced Cost = 15.5308
# Warehouse_DEN to Detroit using DHL: Reduced Cost = 0.2222
# Warehouse_DEN to Detroit using FedEx: Reduced Cost = 31.9368
# Warehouse_DEN to Detroit using LaserShip: Reduced Cost = 1.2265
# Warehouse_DEN to Detroit using OnTrac: Reduced Cost = 82.3362
# Warehouse_DEN to Detroit using UPS: Reduced Cost = 17.4479
# Warehouse_DEN to Detroit using USPS: Reduced Cost = 49.7190
# Warehouse_DEN to Houston using Amazon Logistics: Reduced Cost = 11.1773
# Warehouse_DEN to Houston using DHL: Reduced Cost = 24.3841
# Warehouse_DEN to Houston using FedEx: Reduced Cost = 43.1271
# Warehouse_DEN to Houston using LaserShip: Reduced Cost = 30.0177
# Warehouse_DEN to Houston using OnTrac: Reduced Cost = 36.6608
# Warehouse_DEN to Houston using UPS: Reduced Cost = 39.4965
# Warehouse_DEN to Houston using USPS: Reduced Cost = 0.2222
# Warehouse_DEN to Los Angeles using Amazon Logistics: Reduced Cost = 14.2399
# Warehouse_DEN to Los Angeles using DHL: Reduced Cost = 0.2222
# Warehouse_DEN to Los Angeles using FedEx: Reduced Cost = 68.4073
# Warehouse_DEN to Los Angeles using LaserShip: Reduced Cost = 8.6047
# Warehouse_DEN to Los Angeles using OnTrac: Reduced Cost = 39.6203
# Warehouse_DEN to Los Angeles using UPS: Reduced Cost = 34.0991
# Warehouse_DEN to Los Angeles using USPS: Reduced Cost = 21.7584
# Warehouse_DEN to Miami using Amazon Logistics: Reduced Cost = 18.0748
# Warehouse_DEN to Miami using DHL: Reduced Cost = 42.1655
# Warehouse_DEN to Miami using FedEx: Reduced Cost = 1.1713
# Warehouse_DEN to Miami using LaserShip: Reduced Cost = 0.0000
# Warehouse_DEN to Miami using OnTrac: Reduced Cost = 52.5288
# Warehouse_DEN to Miami using UPS: Reduced Cost = 10.7925
# Warehouse_DEN to Miami using USPS: Reduced Cost = 28.5787
# Warehouse_DEN to Minneapolis using Amazon Logistics: Reduced Cost = 9.8279
# Warehouse_DEN to Minneapolis using DHL: Reduced Cost = 19.0973
# Warehouse_DEN to Minneapolis using FedEx: Reduced Cost = 21.1720
# Warehouse_DEN to Minneapolis using LaserShip: Reduced Cost = 13.9965
# Warehouse_DEN to Minneapolis using OnTrac: Reduced Cost = 30.0172
# Warehouse_DEN to Minneapolis using UPS: Reduced Cost = 0.2222
# Warehouse_DEN to Minneapolis using USPS: Reduced Cost = 50.2088
# Warehouse_DEN to New York using Amazon Logistics: Reduced Cost = 8.8985
# Warehouse_DEN to New York using DHL: Reduced Cost = 48.0887
# Warehouse_DEN to New York using FedEx: Reduced Cost = 24.3866
# Warehouse_DEN to New York using LaserShip: Reduced Cost = 13.8726
# Warehouse_DEN to New York using OnTrac: Reduced Cost = 22.7951
# Warehouse_DEN to New York using UPS: Reduced Cost = 19.5920
# Warehouse_DEN to New York using USPS: Reduced Cost = 17.5309
# Warehouse_DEN to Phoenix using Amazon Logistics: Reduced Cost = 10.3258
# Warehouse_DEN to Phoenix using DHL: Reduced Cost = 26.4171
# Warehouse_DEN to Phoenix using FedEx: Reduced Cost = 16.7338
# Warehouse_DEN to Phoenix using LaserShip: Reduced Cost = 4.5172
# Warehouse_DEN to Phoenix using OnTrac: Reduced Cost = 74.7270
# Warehouse_DEN to Phoenix using UPS: Reduced Cost = 0.6043
# Warehouse_DEN to Phoenix using USPS: Reduced Cost = 10.8238
# Warehouse_DEN to Portland using Amazon Logistics: Reduced Cost = 0.0000
# Warehouse_DEN to Portland using DHL: Reduced Cost = 0.2222
# Warehouse_DEN to Portland using FedEx: Reduced Cost = 26.2495
# Warehouse_DEN to Portland using LaserShip: Reduced Cost = 18.8384
# Warehouse_DEN to Portland using OnTrac: Reduced Cost = 0.2222
# Warehouse_DEN to Portland using UPS: Reduced Cost = 23.2018
# Warehouse_DEN to Portland using USPS: Reduced Cost = 31.4583
# Warehouse_DEN to San Francisco using Amazon Logistics: Reduced Cost = 4.0478
# Warehouse_DEN to San Francisco using DHL: Reduced Cost = 37.0612
# Warehouse_DEN to San Francisco using FedEx: Reduced Cost = 25.9182
# Warehouse_DEN to San Francisco using LaserShip: Reduced Cost = 27.3385
# Warehouse_DEN to San Francisco using OnTrac: Reduced Cost = 38.2261
# Warehouse_DEN to San Francisco using UPS: Reduced Cost = 26.4169
# Warehouse_DEN to San Francisco using USPS: Reduced Cost = 14.4111
# Warehouse_DEN to Seattle using Amazon Logistics: Reduced Cost = 40.7897
# Warehouse_DEN to Seattle using DHL: Reduced Cost = 3.3424
# Warehouse_DEN to Seattle using FedEx: Reduced Cost = 27.1747
# Warehouse_DEN to Seattle using LaserShip: Reduced Cost = 4.3467
# Warehouse_DEN to Seattle using OnTrac: Reduced Cost = 29.1806
# Warehouse_DEN to Seattle using UPS: Reduced Cost = 37.4642
# Warehouse_DEN to Seattle using USPS: Reduced Cost = 59.6593
# Warehouse_HOU to Atlanta using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_HOU to Atlanta using DHL: Reduced Cost = 23.9141
# Warehouse_HOU to Atlanta using FedEx: Reduced Cost = 13.3052
# Warehouse_HOU to Atlanta using LaserShip: Reduced Cost = 7.1138
# Warehouse_HOU to Atlanta using OnTrac: Reduced Cost = 14.5113
# Warehouse_HOU to Atlanta using UPS: Reduced Cost = 17.0564
# Warehouse_HOU to Atlanta using USPS: Reduced Cost = 13.5936
# Warehouse_HOU to Boston using Amazon Logistics: Reduced Cost = 15.2847
# Warehouse_HOU to Boston using DHL: Reduced Cost = 44.9655
# Warehouse_HOU to Boston using FedEx: Reduced Cost = 18.4527
# Warehouse_HOU to Boston using LaserShip: Reduced Cost = 33.4762
# Warehouse_HOU to Boston using OnTrac: Reduced Cost = 15.9460
# Warehouse_HOU to Boston using UPS: Reduced Cost = 7.2337
# Warehouse_HOU to Boston using USPS: Reduced Cost = 23.7006
# Warehouse_HOU to Chicago using Amazon Logistics: Reduced Cost = 10.2816
# Warehouse_HOU to Chicago using DHL: Reduced Cost = 40.1159
# Warehouse_HOU to Chicago using FedEx: Reduced Cost = 1.5252
# Warehouse_HOU to Chicago using LaserShip: Reduced Cost = 26.6914
# Warehouse_HOU to Chicago using OnTrac: Reduced Cost = 21.5856
# Warehouse_HOU to Chicago using UPS: Reduced Cost = 18.8928
# Warehouse_HOU to Chicago using USPS: Reduced Cost = 30.9415
# Warehouse_HOU to Dallas using Amazon Logistics: Reduced Cost = 20.5392
# Warehouse_HOU to Dallas using DHL: Reduced Cost = 7.2299
# Warehouse_HOU to Dallas using FedEx: Reduced Cost = 12.2004
# Warehouse_HOU to Dallas using LaserShip: Reduced Cost = 12.2557
# Warehouse_HOU to Dallas using OnTrac: Reduced Cost = 34.6616
# Warehouse_HOU to Dallas using UPS: Reduced Cost = 20.5499
# Warehouse_HOU to Dallas using USPS: Reduced Cost = 0.0000
# Warehouse_HOU to Denver using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_HOU to Denver using DHL: Reduced Cost = 24.7514
# Warehouse_HOU to Denver using FedEx: Reduced Cost = 14.8252
# Warehouse_HOU to Denver using LaserShip: Reduced Cost = 10.9303
# Warehouse_HOU to Denver using OnTrac: Reduced Cost = 21.0204
# Warehouse_HOU to Denver using UPS: Reduced Cost = 19.7926
# Warehouse_HOU to Denver using USPS: Reduced Cost = 0.0000
# Warehouse_HOU to Detroit using Amazon Logistics: Reduced Cost = 16.1829
# Warehouse_HOU to Detroit using DHL: Reduced Cost = 23.4058
# Warehouse_HOU to Detroit using FedEx: Reduced Cost = 54.9052
# Warehouse_HOU to Detroit using LaserShip: Reduced Cost = 27.6118
# Warehouse_HOU to Detroit using OnTrac: Reduced Cost = 39.3558
# Warehouse_HOU to Detroit using UPS: Reduced Cost = 158.0153
# Warehouse_HOU to Detroit using USPS: Reduced Cost = 11.2597
# Warehouse_HOU to Houston using Amazon Logistics: Reduced Cost = 9.7280
# Warehouse_HOU to Houston using DHL: Reduced Cost = 0.0000
# Warehouse_HOU to Houston using FedEx: Reduced Cost = 0.0000
# Warehouse_HOU to Houston using LaserShip: Reduced Cost = 15.0619
# Warehouse_HOU to Houston using OnTrac: Reduced Cost = 14.8686
# Warehouse_HOU to Houston using UPS: Reduced Cost = 17.9126
# Warehouse_HOU to Houston using USPS: Reduced Cost = 18.1012
# Warehouse_HOU to Los Angeles using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_HOU to Los Angeles using DHL: Reduced Cost = 22.9321
# Warehouse_HOU to Los Angeles using FedEx: Reduced Cost = 0.0000
# Warehouse_HOU to Los Angeles using LaserShip: Reduced Cost = 13.5475
# Warehouse_HOU to Los Angeles using OnTrac: Reduced Cost = 47.3400
# Warehouse_HOU to Los Angeles using UPS: Reduced Cost = 38.6638
# Warehouse_HOU to Los Angeles using USPS: Reduced Cost = 23.0605
# Warehouse_HOU to Miami using Amazon Logistics: Reduced Cost = 30.8645
# Warehouse_HOU to Miami using DHL: Reduced Cost = 44.8540
# Warehouse_HOU to Miami using FedEx: Reduced Cost = 23.0265
# Warehouse_HOU to Miami using LaserShip: Reduced Cost = 14.3508
# Warehouse_HOU to Miami using OnTrac: Reduced Cost = 20.9232
# Warehouse_HOU to Miami using UPS: Reduced Cost = 28.6092
# Warehouse_HOU to Miami using USPS: Reduced Cost = 22.1073
# Warehouse_HOU to Minneapolis using Amazon Logistics: Reduced Cost = 26.3198
# Warehouse_HOU to Minneapolis using DHL: Reduced Cost = 24.7770
# Warehouse_HOU to Minneapolis using FedEx: Reduced Cost = 10.9969
# Warehouse_HOU to Minneapolis using LaserShip: Reduced Cost = 1.0044
# Warehouse_HOU to Minneapolis using OnTrac: Reduced Cost = 27.2423
# Warehouse_HOU to Minneapolis using UPS: Reduced Cost = 39.0409
# Warehouse_HOU to Minneapolis using USPS: Reduced Cost = 26.1838
# Warehouse_HOU to New York using Amazon Logistics: Reduced Cost = 15.9182
# Warehouse_HOU to New York using DHL: Reduced Cost = 37.1931
# Warehouse_HOU to New York using FedEx: Reduced Cost = 23.9072
# Warehouse_HOU to New York using LaserShip: Reduced Cost = 26.8383
# Warehouse_HOU to New York using OnTrac: Reduced Cost = 15.1193
# Warehouse_HOU to New York using UPS: Reduced Cost = 53.7318
# Warehouse_HOU to New York using USPS: Reduced Cost = 25.3743
# Warehouse_HOU to Phoenix using Amazon Logistics: Reduced Cost = 11.2799
# Warehouse_HOU to Phoenix using DHL: Reduced Cost = 44.4913
# Warehouse_HOU to Phoenix using FedEx: Reduced Cost = 44.0769
# Warehouse_HOU to Phoenix using LaserShip: Reduced Cost = 7.7156
# Warehouse_HOU to Phoenix using OnTrac: Reduced Cost = 28.2931
# Warehouse_HOU to Phoenix using UPS: Reduced Cost = 28.9746
# Warehouse_HOU to Phoenix using USPS: Reduced Cost = 28.8729
# Warehouse_HOU to Portland using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_HOU to Portland using DHL: Reduced Cost = 56.8521
# Warehouse_HOU to Portland using FedEx: Reduced Cost = 11.6240
# Warehouse_HOU to Portland using LaserShip: Reduced Cost = 20.0426
# Warehouse_HOU to Portland using OnTrac: Reduced Cost = 0.0000
# Warehouse_HOU to Portland using UPS: Reduced Cost = 44.8608
# Warehouse_HOU to Portland using USPS: Reduced Cost = 17.6862
# Warehouse_HOU to San Francisco using Amazon Logistics: Reduced Cost = 5.3567
# Warehouse_HOU to San Francisco using DHL: Reduced Cost = 0.0000
# Warehouse_HOU to San Francisco using FedEx: Reduced Cost = 20.4855
# Warehouse_HOU to San Francisco using LaserShip: Reduced Cost = 9.9874
# Warehouse_HOU to San Francisco using OnTrac: Reduced Cost = 40.1481
# Warehouse_HOU to San Francisco using UPS: Reduced Cost = 21.7897
# Warehouse_HOU to San Francisco using USPS: Reduced Cost = 26.1031
# Warehouse_HOU to Seattle using Amazon Logistics: Reduced Cost = 39.4975
# Warehouse_HOU to Seattle using DHL: Reduced Cost = 56.4731
# Warehouse_HOU to Seattle using FedEx: Reduced Cost = 35.4580
# Warehouse_HOU to Seattle using LaserShip: Reduced Cost = 49.1986
# Warehouse_HOU to Seattle using OnTrac: Reduced Cost = 15.6300
# Warehouse_HOU to Seattle using UPS: Reduced Cost = 5.9189
# Warehouse_HOU to Seattle using USPS: Reduced Cost = 3.1202
# Warehouse_LA to Atlanta using Amazon Logistics: Reduced Cost = 19.0402
# Warehouse_LA to Atlanta using DHL: Reduced Cost = 29.0459
# Warehouse_LA to Atlanta using FedEx: Reduced Cost = 24.6044
# Warehouse_LA to Atlanta using LaserShip: Reduced Cost = 22.6694
# Warehouse_LA to Atlanta using OnTrac: Reduced Cost = 0.0000
# Warehouse_LA to Atlanta using UPS: Reduced Cost = 15.8633
# Warehouse_LA to Atlanta using USPS: Reduced Cost = 43.1693
# Warehouse_LA to Boston using Amazon Logistics: Reduced Cost = 14.1236
# Warehouse_LA to Boston using DHL: Reduced Cost = 36.6311
# Warehouse_LA to Boston using FedEx: Reduced Cost = 0.0000
# Warehouse_LA to Boston using LaserShip: Reduced Cost = 0.3532
# Warehouse_LA to Boston using OnTrac: Reduced Cost = 7.7136
# Warehouse_LA to Boston using UPS: Reduced Cost = 23.9827
# Warehouse_LA to Boston using USPS: Reduced Cost = 24.0982
# Warehouse_LA to Chicago using Amazon Logistics: Reduced Cost = 12.7557
# Warehouse_LA to Chicago using DHL: Reduced Cost = 37.3601
# Warehouse_LA to Chicago using FedEx: Reduced Cost = 12.5404
# Warehouse_LA to Chicago using LaserShip: Reduced Cost = 20.8895
# Warehouse_LA to Chicago using OnTrac: Reduced Cost = 15.7850
# Warehouse_LA to Chicago using UPS: Reduced Cost = 40.0093
# Warehouse_LA to Chicago using USPS: Reduced Cost = 32.7359
# Warehouse_LA to Dallas using Amazon Logistics: Reduced Cost = 13.2124
# Warehouse_LA to Dallas using DHL: Reduced Cost = 47.2861
# Warehouse_LA to Dallas using FedEx: Reduced Cost = 18.8654
# Warehouse_LA to Dallas using LaserShip: Reduced Cost = 16.2162
# Warehouse_LA to Dallas using OnTrac: Reduced Cost = 28.7637
# Warehouse_LA to Dallas using UPS: Reduced Cost = 35.6440
# Warehouse_LA to Dallas using USPS: Reduced Cost = 25.8500
# Warehouse_LA to Denver using Amazon Logistics: Reduced Cost = 12.3239
# Warehouse_LA to Denver using DHL: Reduced Cost = 64.5571
# Warehouse_LA to Denver using FedEx: Reduced Cost = 36.2716
# Warehouse_LA to Denver using LaserShip: Reduced Cost = 13.5085
# Warehouse_LA to Denver using OnTrac: Reduced Cost = 21.7382
# Warehouse_LA to Denver using UPS: Reduced Cost = 18.4294
# Warehouse_LA to Denver using USPS: Reduced Cost = 32.6157
# Warehouse_LA to Detroit using Amazon Logistics: Reduced Cost = 1.4926
# Warehouse_LA to Detroit using DHL: Reduced Cost = 11.0293
# Warehouse_LA to Detroit using FedEx: Reduced Cost = 23.5607
# Warehouse_LA to Detroit using LaserShip: Reduced Cost = 6.0052
# Warehouse_LA to Detroit using OnTrac: Reduced Cost = 0.0000
# Warehouse_LA to Detroit using UPS: Reduced Cost = 13.5761
# Warehouse_LA to Detroit using USPS: Reduced Cost = 40.6134
# Warehouse_LA to Houston using Amazon Logistics: Reduced Cost = 19.5505
# Warehouse_LA to Houston using DHL: Reduced Cost = 22.8376
# Warehouse_LA to Houston using FedEx: Reduced Cost = 31.7165
# Warehouse_LA to Houston using LaserShip: Reduced Cost = 19.3812
# Warehouse_LA to Houston using OnTrac: Reduced Cost = 7.8516
# Warehouse_LA to Houston using UPS: Reduced Cost = 0.0000
# Warehouse_LA to Houston using USPS: Reduced Cost = 19.0239
# Warehouse_LA to Los Angeles using Amazon Logistics: Reduced Cost = 35.4588
# Warehouse_LA to Los Angeles using DHL: Reduced Cost = 32.8419
# Warehouse_LA to Los Angeles using FedEx: Reduced Cost = 23.3580
# Warehouse_LA to Los Angeles using LaserShip: Reduced Cost = 16.1927
# Warehouse_LA to Los Angeles using OnTrac: Reduced Cost = 38.6332
# Warehouse_LA to Los Angeles using UPS: Reduced Cost = 25.5623
# Warehouse_LA to Los Angeles using USPS: Reduced Cost = 45.7018
# Warehouse_LA to Miami using Amazon Logistics: Reduced Cost = 18.0139
# Warehouse_LA to Miami using DHL: Reduced Cost = 17.6206
# Warehouse_LA to Miami using FedEx: Reduced Cost = 0.9491
# Warehouse_LA to Miami using LaserShip: Reduced Cost = 17.5845
# Warehouse_LA to Miami using OnTrac: Reduced Cost = 39.1469
# Warehouse_LA to Miami using UPS: Reduced Cost = 10.7643
# Warehouse_LA to Miami using USPS: Reduced Cost = 15.6401
# Warehouse_LA to Minneapolis using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_LA to Minneapolis using DHL: Reduced Cost = 0.0000
# Warehouse_LA to Minneapolis using FedEx: Reduced Cost = 18.5256
# Warehouse_LA to Minneapolis using LaserShip: Reduced Cost = 15.0130
# Warehouse_LA to Minneapolis using OnTrac: Reduced Cost = 59.5746
# Warehouse_LA to Minneapolis using UPS: Reduced Cost = 38.5922
# Warehouse_LA to Minneapolis using USPS: Reduced Cost = 37.2315
# Warehouse_LA to New York using Amazon Logistics: Reduced Cost = 31.3503
# Warehouse_LA to New York using DHL: Reduced Cost = 23.1332
# Warehouse_LA to New York using FedEx: Reduced Cost = 32.7730
# Warehouse_LA to New York using LaserShip: Reduced Cost = 18.2454
# Warehouse_LA to New York using OnTrac: Reduced Cost = 20.7106
# Warehouse_LA to New York using UPS: Reduced Cost = 19.5374
# Warehouse_LA to New York using USPS: Reduced Cost = 17.7558
# Warehouse_LA to Phoenix using Amazon Logistics: Reduced Cost = 2.1478
# Warehouse_LA to Phoenix using DHL: Reduced Cost = 12.4113
# Warehouse_LA to Phoenix using FedEx: Reduced Cost = 0.3821
# Warehouse_LA to Phoenix using LaserShip: Reduced Cost = 3.6502
# Warehouse_LA to Phoenix using OnTrac: Reduced Cost = 4.9417
# Warehouse_LA to Phoenix using UPS: Reduced Cost = 4.8852
# Warehouse_LA to Phoenix using USPS: Reduced Cost = 2.1083
# Warehouse_LA to Portland using Amazon Logistics: Reduced Cost = 20.8724
# Warehouse_LA to Portland using DHL: Reduced Cost = 64.1098
# Warehouse_LA to Portland using FedEx: Reduced Cost = 21.8579
# Warehouse_LA to Portland using LaserShip: Reduced Cost = 8.8972
# Warehouse_LA to Portland using OnTrac: Reduced Cost = 34.1738
# Warehouse_LA to Portland using UPS: Reduced Cost = 42.2722
# Warehouse_LA to Portland using USPS: Reduced Cost = 13.7318
# Warehouse_LA to San Francisco using Amazon Logistics: Reduced Cost = 18.8739
# Warehouse_LA to San Francisco using DHL: Reduced Cost = 24.7606
# Warehouse_LA to San Francisco using FedEx: Reduced Cost = 8.4571
# Warehouse_LA to San Francisco using LaserShip: Reduced Cost = 70.6650
# Warehouse_LA to San Francisco using OnTrac: Reduced Cost = 36.5847
# Warehouse_LA to San Francisco using UPS: Reduced Cost = 16.7079
# Warehouse_LA to San Francisco using USPS: Reduced Cost = 23.8091
# Warehouse_LA to Seattle using Amazon Logistics: Reduced Cost = 7.8332
# Warehouse_LA to Seattle using DHL: Reduced Cost = 3.1202
# Warehouse_LA to Seattle using FedEx: Reduced Cost = 18.7359
# Warehouse_LA to Seattle using LaserShip: Reduced Cost = 15.1093
# Warehouse_LA to Seattle using OnTrac: Reduced Cost = 26.9227
# Warehouse_LA to Seattle using UPS: Reduced Cost = 24.4123
# Warehouse_LA to Seattle using USPS: Reduced Cost = 23.5394
# Warehouse_MIA to Atlanta using Amazon Logistics: Reduced Cost = 9.4290
# Warehouse_MIA to Atlanta using DHL: Reduced Cost = 31.2618
# Warehouse_MIA to Atlanta using FedEx: Reduced Cost = 16.8984
# Warehouse_MIA to Atlanta using LaserShip: Reduced Cost = 1.0044
# Warehouse_MIA to Atlanta using OnTrac: Reduced Cost = 26.9187
# Warehouse_MIA to Atlanta using UPS: Reduced Cost = 0.0000
# Warehouse_MIA to Atlanta using USPS: Reduced Cost = 19.9795
# Warehouse_MIA to Boston using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_MIA to Boston using DHL: Reduced Cost = 47.0871
# Warehouse_MIA to Boston using FedEx: Reduced Cost = 40.2467
# Warehouse_MIA to Boston using LaserShip: Reduced Cost = 1.0044
# Warehouse_MIA to Boston using OnTrac: Reduced Cost = 51.5965
# Warehouse_MIA to Boston using UPS: Reduced Cost = 14.2116
# Warehouse_MIA to Boston using USPS: Reduced Cost = 28.7865
# Warehouse_MIA to Chicago using Amazon Logistics: Reduced Cost = 18.5003
# Warehouse_MIA to Chicago using DHL: Reduced Cost = 24.1375
# Warehouse_MIA to Chicago using FedEx: Reduced Cost = 37.5794
# Warehouse_MIA to Chicago using LaserShip: Reduced Cost = 8.7268
# Warehouse_MIA to Chicago using OnTrac: Reduced Cost = 14.4385
# Warehouse_MIA to Chicago using UPS: Reduced Cost = 36.7314
# Warehouse_MIA to Chicago using USPS: Reduced Cost = 22.5536
# Warehouse_MIA to Dallas using Amazon Logistics: Reduced Cost = 16.2744
# Warehouse_MIA to Dallas using DHL: Reduced Cost = 0.0000
# Warehouse_MIA to Dallas using FedEx: Reduced Cost = 2.2403
# Warehouse_MIA to Dallas using LaserShip: Reduced Cost = 1.0044
# Warehouse_MIA to Dallas using OnTrac: Reduced Cost = 80.6106
# Warehouse_MIA to Dallas using UPS: Reduced Cost = 27.0659
# Warehouse_MIA to Dallas using USPS: Reduced Cost = 41.8848
# Warehouse_MIA to Denver using Amazon Logistics: Reduced Cost = 8.8629
# Warehouse_MIA to Denver using DHL: Reduced Cost = 0.0000
# Warehouse_MIA to Denver using FedEx: Reduced Cost = 13.3924
# Warehouse_MIA to Denver using LaserShip: Reduced Cost = 17.7249
# Warehouse_MIA to Denver using OnTrac: Reduced Cost = 7.6412
# Warehouse_MIA to Denver using UPS: Reduced Cost = 15.8053
# Warehouse_MIA to Denver using USPS: Reduced Cost = 29.3298
# Warehouse_MIA to Detroit using Amazon Logistics: Reduced Cost = 15.6776
# Warehouse_MIA to Detroit using DHL: Reduced Cost = 31.8402
# Warehouse_MIA to Detroit using FedEx: Reduced Cost = 0.0000
# Warehouse_MIA to Detroit using LaserShip: Reduced Cost = 16.7532
# Warehouse_MIA to Detroit using OnTrac: Reduced Cost = 34.9377
# Warehouse_MIA to Detroit using UPS: Reduced Cost = 34.9109
# Warehouse_MIA to Detroit using USPS: Reduced Cost = 20.5328
# Warehouse_MIA to Houston using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_MIA to Houston using DHL: Reduced Cost = 0.0000
# Warehouse_MIA to Houston using FedEx: Reduced Cost = 0.0362
# Warehouse_MIA to Houston using LaserShip: Reduced Cost = 8.8881
# Warehouse_MIA to Houston using OnTrac: Reduced Cost = 15.8115
# Warehouse_MIA to Houston using UPS: Reduced Cost = 28.4512
# Warehouse_MIA to Houston using USPS: Reduced Cost = 41.2651
# Warehouse_MIA to Los Angeles using Amazon Logistics: Reduced Cost = 21.8835
# Warehouse_MIA to Los Angeles using DHL: Reduced Cost = 38.6356
# Warehouse_MIA to Los Angeles using FedEx: Reduced Cost = 16.2479
# Warehouse_MIA to Los Angeles using LaserShip: Reduced Cost = 9.1878
# Warehouse_MIA to Los Angeles using OnTrac: Reduced Cost = 32.1860
# Warehouse_MIA to Los Angeles using UPS: Reduced Cost = 30.1035
# Warehouse_MIA to Los Angeles using USPS: Reduced Cost = 0.0000
# Warehouse_MIA to Miami using Amazon Logistics: Reduced Cost = 1.4243
# Warehouse_MIA to Miami using DHL: Reduced Cost = 0.9491
# Warehouse_MIA to Miami using FedEx: Reduced Cost = 24.1729
# Warehouse_MIA to Miami using LaserShip: Reduced Cost = 12.5985
# Warehouse_MIA to Miami using OnTrac: Reduced Cost = 0.9491
# Warehouse_MIA to Miami using UPS: Reduced Cost = 27.3362
# Warehouse_MIA to Miami using USPS: Reduced Cost = 0.9491
# Warehouse_MIA to Minneapolis using Amazon Logistics: Reduced Cost = 21.4803
# Warehouse_MIA to Minneapolis using DHL: Reduced Cost = 50.9516
# Warehouse_MIA to Minneapolis using FedEx: Reduced Cost = 18.9956
# Warehouse_MIA to Minneapolis using LaserShip: Reduced Cost = 24.2098
# Warehouse_MIA to Minneapolis using OnTrac: Reduced Cost = 53.0094
# Warehouse_MIA to Minneapolis using UPS: Reduced Cost = 0.0000
# Warehouse_MIA to Minneapolis using USPS: Reduced Cost = 29.9548
# Warehouse_MIA to New York using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_MIA to New York using DHL: Reduced Cost = 32.1219
# Warehouse_MIA to New York using FedEx: Reduced Cost = 37.3618
# Warehouse_MIA to New York using LaserShip: Reduced Cost = 11.9631
# Warehouse_MIA to New York using OnTrac: Reduced Cost = 41.2351
# Warehouse_MIA to New York using UPS: Reduced Cost = 25.7385
# Warehouse_MIA to New York using USPS: Reduced Cost = 17.3624
# Warehouse_MIA to Phoenix using Amazon Logistics: Reduced Cost = 14.0046
# Warehouse_MIA to Phoenix using DHL: Reduced Cost = 51.0235
# Warehouse_MIA to Phoenix using FedEx: Reduced Cost = 9.4007
# Warehouse_MIA to Phoenix using LaserShip: Reduced Cost = 26.6830
# Warehouse_MIA to Phoenix using OnTrac: Reduced Cost = 8.3278
# Warehouse_MIA to Phoenix using UPS: Reduced Cost = 8.4905
# Warehouse_MIA to Phoenix using USPS: Reduced Cost = 44.9008
# Warehouse_MIA to Portland using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_MIA to Portland using DHL: Reduced Cost = 49.2112
# Warehouse_MIA to Portland using FedEx: Reduced Cost = 25.5701
# Warehouse_MIA to Portland using LaserShip: Reduced Cost = 6.2943
# Warehouse_MIA to Portland using OnTrac: Reduced Cost = 47.1128
# Warehouse_MIA to Portland using UPS: Reduced Cost = 31.0217
# Warehouse_MIA to Portland using USPS: Reduced Cost = 18.9651
# Warehouse_MIA to San Francisco using Amazon Logistics: Reduced Cost = 13.9795
# Warehouse_MIA to San Francisco using DHL: Reduced Cost = 39.3509
# Warehouse_MIA to San Francisco using FedEx: Reduced Cost = 0.0000
# Warehouse_MIA to San Francisco using LaserShip: Reduced Cost = 20.3534
# Warehouse_MIA to San Francisco using OnTrac: Reduced Cost = 15.8809
# Warehouse_MIA to San Francisco using UPS: Reduced Cost = 27.9357
# Warehouse_MIA to San Francisco using USPS: Reduced Cost = 0.0000
# Warehouse_MIA to Seattle using Amazon Logistics: Reduced Cost = 14.4553
# Warehouse_MIA to Seattle using DHL: Reduced Cost = 41.4110
# Warehouse_MIA to Seattle using FedEx: Reduced Cost = 3.1202
# Warehouse_MIA to Seattle using LaserShip: Reduced Cost = 12.0062
# Warehouse_MIA to Seattle using OnTrac: Reduced Cost = 3.0057
# Warehouse_MIA to Seattle using UPS: Reduced Cost = 32.9348
# Warehouse_MIA to Seattle using USPS: Reduced Cost = 3.1202
# Warehouse_NYC to Atlanta using Amazon Logistics: Reduced Cost = 1.7240
# ...
# Warehouse_NYC to Miami using UPS: Reduced Cost = 3.8436
# Warehouse_NYC to Miami using USPS: Reduced Cost = 25.2805
# Warehouse_NYC to Minneapolis using Amazon Logistics: Reduced Cost = 13.3861
# Warehouse_NYC to Minneapolis using DHL: Reduced Cost = 12.1267
# Warehouse_NYC to Minneapolis using FedEx: Reduced Cost = 25.2753
# Warehouse_NYC to Minneapolis using LaserShip: Reduced Cost = 2.2532
# Warehouse_NYC to Minneapolis using OnTrac: Reduced Cost = 11.6678
# Warehouse_NYC to Minneapolis using UPS: Reduced Cost = 38.8967
# Warehouse_NYC to Minneapolis using USPS: Reduced Cost = 20.2596
# Warehouse_NYC to New York using Amazon Logistics: Reduced Cost = 1.7240
# Warehouse_NYC to New York using DHL: Reduced Cost = 54.7167
# Warehouse_NYC to New York using FedEx: Reduced Cost = 1.2488
# Warehouse_NYC to New York using LaserShip: Reduced Cost = 14.1485
# Warehouse_NYC to New York using OnTrac: Reduced Cost = 1.2488
# Warehouse_NYC to New York using UPS: Reduced Cost = 24.0742
# Warehouse_NYC to New York using USPS: Reduced Cost = 1.2488
# Warehouse_NYC to Phoenix using Amazon Logistics: Reduced Cost = 22.4165
# Warehouse_NYC to Phoenix using DHL: Reduced Cost = 24.1699
# Warehouse_NYC to Phoenix using FedEx: Reduced Cost = 46.1280
# Warehouse_NYC to Phoenix using LaserShip: Reduced Cost = 2.6353
# Warehouse_NYC to Phoenix using OnTrac: Reduced Cost = 20.2102
# Warehouse_NYC to Phoenix using UPS: Reduced Cost = 37.0010
# Warehouse_NYC to Phoenix using USPS: Reduced Cost = 29.9975
# Warehouse_NYC to Portland using Amazon Logistics: Reduced Cost = 61.0231
# Warehouse_NYC to Portland using DHL: Reduced Cost = 47.5833
# Warehouse_NYC to Portland using FedEx: Reduced Cost = 47.9108
# Warehouse_NYC to Portland using LaserShip: Reduced Cost = 18.9769
# Warehouse_NYC to Portland using OnTrac: Reduced Cost = 21.1188
# Warehouse_NYC to Portland using UPS: Reduced Cost = 20.1829
# Warehouse_NYC to Portland using USPS: Reduced Cost = 34.6029
# Warehouse_NYC to San Francisco using Amazon Logistics: Reduced Cost = 5.4563
# Warehouse_NYC to San Francisco using DHL: Reduced Cost = 88.3554
# Warehouse_NYC to San Francisco using FedEx: Reduced Cost = 22.5891
# Warehouse_NYC to San Francisco using LaserShip: Reduced Cost = 17.1417
# Warehouse_NYC to San Francisco using OnTrac: Reduced Cost = 1.2488
# Warehouse_NYC to San Francisco using UPS: Reduced Cost = 43.9776
# Warehouse_NYC to San Francisco using USPS: Reduced Cost = 47.4673
# Warehouse_NYC to Seattle using Amazon Logistics: Reduced Cost = 4.8442
# Warehouse_NYC to Seattle using DHL: Reduced Cost = 33.1458
# Warehouse_NYC to Seattle using FedEx: Reduced Cost = 17.0485
# Warehouse_NYC to Seattle using LaserShip: Reduced Cost = 13.8309
# Warehouse_NYC to Seattle using OnTrac: Reduced Cost = 18.5662
# Warehouse_NYC to Seattle using UPS: Reduced Cost = 4.3691
# Warehouse_NYC to Seattle using USPS: Reduced Cost = 35.2820
# Warehouse_SEA to Atlanta using Amazon Logistics: Reduced Cost = 4.6574
# Warehouse_SEA to Atlanta using DHL: Reduced Cost = 22.1575
# Warehouse_SEA to Atlanta using FedEx: Reduced Cost = 23.0906
# Warehouse_SEA to Atlanta using LaserShip: Reduced Cost = 1.0044
# Warehouse_SEA to Atlanta using OnTrac: Reduced Cost = 32.8102
# Warehouse_SEA to Atlanta using UPS: Reduced Cost = 21.8784
# Warehouse_SEA to Atlanta using USPS: Reduced Cost = 0.0000
# Warehouse_SEA to Boston using Amazon Logistics: Reduced Cost = 34.2096
# Warehouse_SEA to Boston using DHL: Reduced Cost = 69.3167
# Warehouse_SEA to Boston using FedEx: Reduced Cost = 30.2891
# Warehouse_SEA to Boston using LaserShip: Reduced Cost = 18.8903
# Warehouse_SEA to Boston using OnTrac: Reduced Cost = 31.4874
# Warehouse_SEA to Boston using UPS: Reduced Cost = 0.0000
# Warehouse_SEA to Boston using USPS: Reduced Cost = 0.0000
# Warehouse_SEA to Chicago using Amazon Logistics: Reduced Cost = 14.3018
# Warehouse_SEA to Chicago using DHL: Reduced Cost = 38.5137
# Warehouse_SEA to Chicago using FedEx: Reduced Cost = 29.8286
# Warehouse_SEA to Chicago using LaserShip: Reduced Cost = 2.5296
# Warehouse_SEA to Chicago using OnTrac: Reduced Cost = 63.8330
# Warehouse_SEA to Chicago using UPS: Reduced Cost = 29.0016
# Warehouse_SEA to Chicago using USPS: Reduced Cost = 28.4336
# Warehouse_SEA to Dallas using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_SEA to Dallas using DHL: Reduced Cost = 30.3360
# Warehouse_SEA to Dallas using FedEx: Reduced Cost = 1.3556
# Warehouse_SEA to Dallas using LaserShip: Reduced Cost = 1.0044
# Warehouse_SEA to Dallas using OnTrac: Reduced Cost = 43.0239
# Warehouse_SEA to Dallas using UPS: Reduced Cost = 24.4391
# Warehouse_SEA to Dallas using USPS: Reduced Cost = 36.2244
# Warehouse_SEA to Denver using Amazon Logistics: Reduced Cost = 48.1405
# Warehouse_SEA to Denver using DHL: Reduced Cost = 41.4344
# Warehouse_SEA to Denver using FedEx: Reduced Cost = 32.5226
# Warehouse_SEA to Denver using LaserShip: Reduced Cost = 14.8891
# Warehouse_SEA to Denver using OnTrac: Reduced Cost = 28.1397
# Warehouse_SEA to Denver using UPS: Reduced Cost = 25.5502
# Warehouse_SEA to Denver using USPS: Reduced Cost = 11.5391
# Warehouse_SEA to Detroit using Amazon Logistics: Reduced Cost = 17.7400
# Warehouse_SEA to Detroit using DHL: Reduced Cost = 35.5836
# Warehouse_SEA to Detroit using FedEx: Reduced Cost = 26.9752
# Warehouse_SEA to Detroit using LaserShip: Reduced Cost = 22.7131
# Warehouse_SEA to Detroit using OnTrac: Reduced Cost = 5.4056
# Warehouse_SEA to Detroit using UPS: Reduced Cost = 19.2428
# Warehouse_SEA to Detroit using USPS: Reduced Cost = 26.9518
# Warehouse_SEA to Houston using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_SEA to Houston using DHL: Reduced Cost = 34.0379
# Warehouse_SEA to Houston using FedEx: Reduced Cost = 19.6203
# Warehouse_SEA to Houston using LaserShip: Reduced Cost = 24.4031
# Warehouse_SEA to Houston using OnTrac: Reduced Cost = 41.6393
# Warehouse_SEA to Houston using UPS: Reduced Cost = 3.0906
# Warehouse_SEA to Houston using USPS: Reduced Cost = 11.7252
# Warehouse_SEA to Los Angeles using Amazon Logistics: Reduced Cost = 38.2223
# Warehouse_SEA to Los Angeles using DHL: Reduced Cost = 39.1299
# Warehouse_SEA to Los Angeles using FedEx: Reduced Cost = 25.9615
# Warehouse_SEA to Los Angeles using LaserShip: Reduced Cost = 4.1586
# Warehouse_SEA to Los Angeles using OnTrac: Reduced Cost = 37.8603
# Warehouse_SEA to Los Angeles using UPS: Reduced Cost = 0.0000
# Warehouse_SEA to Los Angeles using USPS: Reduced Cost = 47.0444
# Warehouse_SEA to Miami using Amazon Logistics: Reduced Cost = 20.3177
# Warehouse_SEA to Miami using DHL: Reduced Cost = 0.9491
# Warehouse_SEA to Miami using FedEx: Reduced Cost = 41.8435
# Warehouse_SEA to Miami using LaserShip: Reduced Cost = 35.3092
# Warehouse_SEA to Miami using OnTrac: Reduced Cost = 0.9491
# Warehouse_SEA to Miami using UPS: Reduced Cost = 23.3701
# Warehouse_SEA to Miami using USPS: Reduced Cost = 31.6791
# Warehouse_SEA to Minneapolis using Amazon Logistics: Reduced Cost = 20.3432
# Warehouse_SEA to Minneapolis using DHL: Reduced Cost = 56.8050
# Warehouse_SEA to Minneapolis using FedEx: Reduced Cost = 31.0922
# Warehouse_SEA to Minneapolis using LaserShip: Reduced Cost = 0.0000
# Warehouse_SEA to Minneapolis using OnTrac: Reduced Cost = 22.0089
# Warehouse_SEA to Minneapolis using UPS: Reduced Cost = 0.0000
# Warehouse_SEA to Minneapolis using USPS: Reduced Cost = 37.3698
# Warehouse_SEA to New York using Amazon Logistics: Reduced Cost = 21.9354
# Warehouse_SEA to New York using DHL: Reduced Cost = 31.0284
# Warehouse_SEA to New York using FedEx: Reduced Cost = 7.3936
# Warehouse_SEA to New York using LaserShip: Reduced Cost = 1.0044
# Warehouse_SEA to New York using OnTrac: Reduced Cost = 16.8115
# Warehouse_SEA to New York using UPS: Reduced Cost = 0.0000
# Warehouse_SEA to New York using USPS: Reduced Cost = 22.2700
# Warehouse_SEA to Phoenix using Amazon Logistics: Reduced Cost = 7.8333
# Warehouse_SEA to Phoenix using DHL: Reduced Cost = 48.3585
# Warehouse_SEA to Phoenix using FedEx: Reduced Cost = 56.3574
# Warehouse_SEA to Phoenix using LaserShip: Reduced Cost = 17.2132
# Warehouse_SEA to Phoenix using OnTrac: Reduced Cost = 13.8430
# Warehouse_SEA to Phoenix using UPS: Reduced Cost = 36.9273
# Warehouse_SEA to Phoenix using USPS: Reduced Cost = 29.3063
# Warehouse_SEA to Portland using Amazon Logistics: Reduced Cost = 28.2071
# Warehouse_SEA to Portland using DHL: Reduced Cost = 18.1708
# Warehouse_SEA to Portland using FedEx: Reduced Cost = 24.0822
# Warehouse_SEA to Portland using LaserShip: Reduced Cost = 14.8156
# Warehouse_SEA to Portland using OnTrac: Reduced Cost = 36.0607
# Warehouse_SEA to Portland using UPS: Reduced Cost = 0.0000
# Warehouse_SEA to Portland using USPS: Reduced Cost = 5.3603
# Warehouse_SEA to San Francisco using Amazon Logistics: Reduced Cost = 23.5085
# Warehouse_SEA to San Francisco using DHL: Reduced Cost = 46.2578
# Warehouse_SEA to San Francisco using FedEx: Reduced Cost = 28.8482
# Warehouse_SEA to San Francisco using LaserShip: Reduced Cost = 1.0044
# Warehouse_SEA to San Francisco using OnTrac: Reduced Cost = 21.7823
# Warehouse_SEA to San Francisco using UPS: Reduced Cost = 34.1692
# Warehouse_SEA to San Francisco using USPS: Reduced Cost = 21.4909
# Warehouse_SEA to Seattle using Amazon Logistics: Reduced Cost = 3.5954
# Warehouse_SEA to Seattle using DHL: Reduced Cost = 47.3294
# Warehouse_SEA to Seattle using FedEx: Reduced Cost = 33.2969
# Warehouse_SEA to Seattle using LaserShip: Reduced Cost = 17.1806
# Warehouse_SEA to Seattle using OnTrac: Reduced Cost = 34.2806
# Warehouse_SEA to Seattle using UPS: Reduced Cost = 33.4424
# Warehouse_SEA to Seattle using USPS: Reduced Cost = 12.0822
# Warehouse_SF to Atlanta using Amazon Logistics: Reduced Cost = 11.7189
# Warehouse_SF to Atlanta using DHL: Reduced Cost = 58.9598
# Warehouse_SF to Atlanta using FedEx: Reduced Cost = 18.0178
# Warehouse_SF to Atlanta using LaserShip: Reduced Cost = 14.8379
# Warehouse_SF to Atlanta using OnTrac: Reduced Cost = 42.6340
# Warehouse_SF to Atlanta using UPS: Reduced Cost = 13.2689
# Warehouse_SF to Atlanta using USPS: Reduced Cost = 6.1113
# Warehouse_SF to Boston using Amazon Logistics: Reduced Cost = 21.6477
# Warehouse_SF to Boston using DHL: Reduced Cost = 42.4826
# Warehouse_SF to Boston using FedEx: Reduced Cost = 10.8136
# Warehouse_SF to Boston using LaserShip: Reduced Cost = 59.4745
# Warehouse_SF to Boston using OnTrac: Reduced Cost = 13.0941
# Warehouse_SF to Boston using UPS: Reduced Cost = 25.2319
# Warehouse_SF to Boston using USPS: Reduced Cost = 23.0817
# Warehouse_SF to Chicago using Amazon Logistics: Reduced Cost = 15.5125
# Warehouse_SF to Chicago using DHL: Reduced Cost = 30.6172
# Warehouse_SF to Chicago using FedEx: Reduced Cost = 1.5252
# Warehouse_SF to Chicago using LaserShip: Reduced Cost = 7.8939
# Warehouse_SF to Chicago using OnTrac: Reduced Cost = 45.8371
# Warehouse_SF to Chicago using UPS: Reduced Cost = 1.5252
# Warehouse_SF to Chicago using USPS: Reduced Cost = 1.5252
# Warehouse_SF to Dallas using Amazon Logistics: Reduced Cost = 10.6259
# Warehouse_SF to Dallas using DHL: Reduced Cost = 0.0000
# Warehouse_SF to Dallas using FedEx: Reduced Cost = 25.6127
# Warehouse_SF to Dallas using LaserShip: Reduced Cost = 25.1057
# Warehouse_SF to Dallas using OnTrac: Reduced Cost = 29.9503
# Warehouse_SF to Dallas using UPS: Reduced Cost = 20.1230
# Warehouse_SF to Dallas using USPS: Reduced Cost = 16.7786
# Warehouse_SF to Denver using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_SF to Denver using DHL: Reduced Cost = 31.9626
# Warehouse_SF to Denver using FedEx: Reduced Cost = 13.3796
# Warehouse_SF to Denver using LaserShip: Reduced Cost = 4.6786
# Warehouse_SF to Denver using OnTrac: Reduced Cost = 14.6600
# Warehouse_SF to Denver using UPS: Reduced Cost = 14.3019
# Warehouse_SF to Denver using USPS: Reduced Cost = 29.5306
# Warehouse_SF to Detroit using Amazon Logistics: Reduced Cost = 0.4752
# Warehouse_SF to Detroit using DHL: Reduced Cost = 45.1247
# Warehouse_SF to Detroit using FedEx: Reduced Cost = 4.5444
# Warehouse_SF to Detroit using LaserShip: Reduced Cost = 15.2282
# Warehouse_SF to Detroit using OnTrac: Reduced Cost = 29.8180
# Warehouse_SF to Detroit using UPS: Reduced Cost = 40.2269
# Warehouse_SF to Detroit using USPS: Reduced Cost = 17.9887
# Warehouse_SF to Houston using Amazon Logistics: Reduced Cost = 34.4685
# Warehouse_SF to Houston using DHL: Reduced Cost = 12.3298
# Warehouse_SF to Houston using FedEx: Reduced Cost = 28.4927
# Warehouse_SF to Houston using LaserShip: Reduced Cost = 7.7265
# Warehouse_SF to Houston using OnTrac: Reduced Cost = 16.4894
# Warehouse_SF to Houston using UPS: Reduced Cost = 21.8189
# Warehouse_SF to Houston using USPS: Reduced Cost = 0.0000
# Warehouse_SF to Los Angeles using Amazon Logistics: Reduced Cost = 20.3568
# Warehouse_SF to Los Angeles using DHL: Reduced Cost = 15.9252
# Warehouse_SF to Los Angeles using FedEx: Reduced Cost = 18.7894
# Warehouse_SF to Los Angeles using LaserShip: Reduced Cost = 19.5926
# Warehouse_SF to Los Angeles using OnTrac: Reduced Cost = 19.9481
# Warehouse_SF to Los Angeles using UPS: Reduced Cost = 0.0000
# Warehouse_SF to Los Angeles using USPS: Reduced Cost = 45.2445
# Warehouse_SF to Miami using Amazon Logistics: Reduced Cost = 29.2888
# Warehouse_SF to Miami using DHL: Reduced Cost = 4.6661
# Warehouse_SF to Miami using FedEx: Reduced Cost = 26.2307
# Warehouse_SF to Miami using LaserShip: Reduced Cost = 24.3298
# Warehouse_SF to Miami using OnTrac: Reduced Cost = 42.7069
# Warehouse_SF to Miami using UPS: Reduced Cost = 50.9594
# Warehouse_SF to Miami using USPS: Reduced Cost = 10.1233
# Warehouse_SF to Minneapolis using Amazon Logistics: Reduced Cost = 22.4279
# Warehouse_SF to Minneapolis using DHL: Reduced Cost = 5.6477
# Warehouse_SF to Minneapolis using FedEx: Reduced Cost = 22.4397
# Warehouse_SF to Minneapolis using LaserShip: Reduced Cost = 19.9673
# Warehouse_SF to Minneapolis using OnTrac: Reduced Cost = 9.8503
# Warehouse_SF to Minneapolis using UPS: Reduced Cost = 0.0000
# Warehouse_SF to Minneapolis using USPS: Reduced Cost = 22.8849
# Warehouse_SF to New York using Amazon Logistics: Reduced Cost = 19.3111
# Warehouse_SF to New York using DHL: Reduced Cost = 50.9896
# Warehouse_SF to New York using FedEx: Reduced Cost = 26.2412
# Warehouse_SF to New York using LaserShip: Reduced Cost = 10.0595
# Warehouse_SF to New York using OnTrac: Reduced Cost = 55.8906
# Warehouse_SF to New York using UPS: Reduced Cost = 9.5590
# Warehouse_SF to New York using USPS: Reduced Cost = 4.2622
# Warehouse_SF to Phoenix using Amazon Logistics: Reduced Cost = 18.3168
# Warehouse_SF to Phoenix using DHL: Reduced Cost = 31.7991
# Warehouse_SF to Phoenix using FedEx: Reduced Cost = 35.4003
# Warehouse_SF to Phoenix using LaserShip: Reduced Cost = 27.8306
# Warehouse_SF to Phoenix using OnTrac: Reduced Cost = 7.3505
# Warehouse_SF to Phoenix using UPS: Reduced Cost = 9.5772
# Warehouse_SF to Phoenix using USPS: Reduced Cost = 26.8655
# Warehouse_SF to Portland using Amazon Logistics: Reduced Cost = 14.1247
# Warehouse_SF to Portland using DHL: Reduced Cost = 22.1501
# Warehouse_SF to Portland using FedEx: Reduced Cost = 11.4574
# Warehouse_SF to Portland using LaserShip: Reduced Cost = 19.5754
# Warehouse_SF to Portland using OnTrac: Reduced Cost = 22.1327
# Warehouse_SF to Portland using UPS: Reduced Cost = 17.7733
# Warehouse_SF to Portland using USPS: Reduced Cost = 18.3600
# Warehouse_SF to San Francisco using Amazon Logistics: Reduced Cost = 8.9386
# Warehouse_SF to San Francisco using DHL: Reduced Cost = 42.7119
# Warehouse_SF to San Francisco using FedEx: Reduced Cost = 20.4009
# Warehouse_SF to San Francisco using LaserShip: Reduced Cost = 4.6449
# Warehouse_SF to San Francisco using OnTrac: Reduced Cost = 25.1620
# Warehouse_SF to San Francisco using UPS: Reduced Cost = 0.0000
# Warehouse_SF to San Francisco using USPS: Reduced Cost = 42.1759
# Warehouse_SF to Seattle using Amazon Logistics: Reduced Cost = 10.0698
# Warehouse_SF to Seattle using DHL: Reduced Cost = 57.4608
# Warehouse_SF to Seattle using FedEx: Reduced Cost = 25.2551
# Warehouse_SF to Seattle using LaserShip: Reduced Cost = 4.1246
# Warehouse_SF to Seattle using OnTrac: Reduced Cost = 50.8647
# Warehouse_SF to Seattle using UPS: Reduced Cost = 14.5785
# Warehouse_SF to Seattle using USPS: Reduced Cost = 31.2773
